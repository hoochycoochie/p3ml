# %% [markdown]
# Le jeu de données Open Food Facts est disponible sur le site officiel (ou disponible à ce lien en téléchargement). Les variables sont définies à cette adresse.
#
# Les champs sont séparés en quatre sections :
#
# Les informations générales sur la fiche du produit : nom, date de modification, etc.
# Un ensemble de tags : catégorie du produit, localisation, origine, etc.
# Les ingrédients composant les produits et leurs additifs éventuels.
# Des informations nutritionnelles : quantité en grammes d’un nutriment pour 100 grammes du produit.

# %% [markdown]
# # Partie 1 Idée d'application
#
# Pour répondre à l'appel de l'Agence française santé publique, et en fonction des données à notre disposition,
# nous proposons une application (web et ou mobile) qui propose des produits et ou catégories de produits au consommateur suivant les caractéristiques suivantes:
# - le pays dans lequel où il réside et où les produits sont disponibles,
# - le sexe
# - l'âge
# - le poids
# - la taille
# - les maladies dont souffre éventuellement le consommateur
# - voir mêmes les éventuelles allergies
#
# Bien entendu, la mise en place d'une application nécessité une collaboration avec des médecins, diététiciens, nutritionnistes afin de connaitre les nutriments et leurs valeurs respectives dont le consommateur a besoin selon sa situation tout minimisant l'impact sur l'environnement voir le nutriscore

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer 
from scipy import stats
#pd.set_option('display.max_rows', None)

# %%
df=pd.read_csv('./food.csv',sep='\t',low_memory=False)

# %%
df.shape ## 320772 lignes et 172 colonnes
# Out:
# (320772, 162)

# %% [markdown]
# Afin de répondre à notre idée d'application ,la première chose qu'on fait reste le filtrage des données par pays.Etant donnée, qu'on vit en France, on s'intéresse aux produits disponibles en France

# %%
## filtrage des produits disponibles en France
df=df[(pd.notnull(df['countries'])) & (
(df['countries'].str.contains('FR')) |
    (df['countries'].str.contains('France'))
    | (df['countries'].str.contains('france'))
    | (df['countries'].str.contains('French'))
     | (df['countries'].str.contains('french'))
)]

# %%
df.isnull().sum()/len(df)*100
# Out:
# code                         0.000000
# url                          0.000000
# creator                      0.000000
# created_t                    0.000000
# created_datetime             0.001019
#                               ...
# carbon-footprint_100g       99.820653
# nutrition-score-fr_100g     37.641388
# nutrition-score-uk_100g     37.641388
# glycemic-index_100g        100.000000
# water-hardness_100g        100.000000
# Length: 162, dtype: float64

# %% [markdown]
# #  Traitements des colonnes

# %%
## fonction renvoyant les colonnes et le pourcentage de valeurs nulles pour chacune d'elle
def columns_na_percentage(df):
    na_df=(df.isnull().sum()/len(df)*100).sort_values(ascending=False).reset_index()
    na_df.columns = ['Column','na_rate_percent']
    return na_df

# %%
## variables comportant plus de 50% de valeurs manquantes
na_df=columns_na_percentage(df)
na_columns=na_df[na_df['na_rate_percent']>=50] ## 120 colonnes ont plus de 50% de valeurs nulles
#na_columns[na_columns['Column']=='manufacturing_places']
na_columns
# Out:
#                   Column  na_rate_percent
# 0    water-hardness_100g       100.000000
# 1     nervonic-acid_100g       100.000000
# 2         mead-acid_100g       100.000000
# 3      gondoic-acid_100g       100.000000
# 4      elaidic-acid_100g       100.000000
# ..                   ...              ...
# 115         generic_name        61.194897
# 116      purchase_places        56.025435
# 117           fiber_100g        53.524772
# 118   carbohydrates_100g        52.130760
# 119             fat_100g        51.691565
#
# [120 rows x 2 columns]

# %%
## suppression des colonnes ayant plus 50% de valeurs nulles
df.drop(columns=na_columns['Column'].tolist(),axis=1,inplace=True)

# %%
## les colonnes code, url,creator,created_t,created_datetime,last_modified_t,last_modified_datetime
  # sont peu utiles, et plus relatives au stockage en base de données
  # par conséquent, nous les supprimons
unuseless_columns =['code', 'url','creator','created_t','created_datetime','last_modified_t','last_modified_datetime']
df.drop(columns=unuseless_columns,axis=1,inplace=True)

# %%
## ['categories','categories_tags','categories_fr','main_category'] restent les mêmes, on ne garde que categories
## ['brands','brands_tags'] restent les mêmes, on ne garde que brands
## ['additives_n','additives'] restent les mêmes, on ne garde que additives_n

## Au final, on ne retient que les variables suivantes
relevant_cols=[
    'product_name',
    
    'categories',
    'additives_n',
    'ingredients_from_palm_oil_n',
    'nutrition_grade_fr',
    
    
    ## toutes les valeurs nutritionnelles
    'energy_100g', 
    'saturated-fat_100g',
    'sugars_100g',
    'proteins_100g',
    'salt_100g', 
    'sodium_100g',
    'nutrition-score-fr_100g',
       
    
]
df=df[relevant_cols]

# %% [markdown]
# ## Traitement des lignes

# %%
## le nom du produit censé être unique et non nul
## suppression de toutes les lignes dont le nom du produit est non renseigné ou nul
missing_product_name=df[(pd.isna(df['product_name']))|(df['product_name'].str.strip()=='')]
missing_product_name[['product_name']] ##7172 lignes à supprimmer
#df=df[~pd.isna(df['product_name'])]
# Out:
#        product_name
# 48              NaN
# 183             NaN
# 187             NaN
# 227             NaN
# 280             NaN
# ...             ...
# 320718          NaN
# 320745          NaN
# 320746          NaN
# 320747          NaN
# 320755          NaN
#
# [7172 rows x 1 columns]

# %%
## suppression des produits dont les noms ne sont pas renseignés
df.drop(missing_product_name.index,inplace=True)

# %%
## vérification de doublons pour le nom du produit 23497 doublons
df[df['product_name'].duplicated(keep=False)][['product_name']]
# Out:
#                product_name
# 0        Farine de blé noir
# 240                     7Up
# 242       Madeleines nature
# 271     Terrine de campagne
# 284        Chair à saucisse
# ...                     ...
# 320711              Lardons
# 320715  Graine couscous fin
# 320743            Gingembre
# 320757              Amandes
# 320760             Poireaux
#
# [23497 rows x 1 columns]

# %%
## suppression des doublons sur les produits
df.drop_duplicates(subset='product_name',keep='last',inplace=True)

# %%
## identification des colonnes décrivant la part nutritionnelle pour 100g
nutriment_cols=[i for i in df.columns.tolist() if i.endswith('_100g')]
nutriment_cols
# Out:
# ['energy_100g',
#  'saturated-fat_100g',
#  'sugars_100g',
#  'proteins_100g',
#  'salt_100g',
#  'sodium_100g',
#  'nutrition-score-fr_100g']

# %%
## vérification des lignes comportant des valeurs nutritionnelles négatives
negative_cols=[]
for col in nutriment_cols:
    if len(df[df[col]<0])>0:
        negative_cols.append(col)

print('columns with negative values',negative_cols) 
## les variables ['sugars_100g', 'fiber_100g', 'proteins_100g', 'nutrition-score-fr_100g']
              ## comportent des valeurs négatives
## suppression des lignes comportant des valeurs nutritionnelles négatives
for col in negative_cols:
    df.drop(index=df.loc[df[col]<0,col].index,inplace=True)
# Out:
# columns with negative values ['sugars_100g', 'nutrition-score-fr_100g']

# %%
## identification des lignes dont toutes les valeurs nutritionnelles sont inconnues
all_missing_nutritional = df[df["energy_100g"].isna()
                            & df["proteins_100g"].isna()
                            & df["sugars_100g"].isna()
                          
            &df['sugars_100g'].isna()
                            
   
                             & df[ 'nutrition-score-fr_100g'].isna()
                           
                            & df["saturated-fat_100g"].isna()
                             
                            & df["sodium_100g"].isna() 
                    ] 
len(all_missing_nutritional[nutriment_cols] )## 21582
# Out:
# 21582

# %%
## suppression des lignes dont toutes les valeurs nutritives sont inconnues ainsi que les nutriscores
df.drop(all_missing_nutritional.index,inplace=True)

# %%
df.isnull().sum()/len(df)*100
# Out:
# product_name                    0.000000
# categories                     28.778580
# additives_n                    33.956071
# ingredients_from_palm_oil_n    33.956071
# nutrition_grade_fr              6.274589
# energy_100g                     0.537308
# saturated-fat_100g              4.552506
# sugars_100g                     4.260246
# proteins_100g                   1.027405
# salt_100g                       4.192801
# sodium_100g                     4.195050
# nutrition-score-fr_100g         6.274589
# dtype: float64

# %% [markdown]
# # Analyse et recherche des valeurs aberrantes avec IQR (Inter Quartile Range)

# %%
df.describe()
# Out:
#         additives_n  ingredients_from_palm_oil_n    energy_100g  \
# count  29377.000000                 29377.000000   44242.000000
# mean       2.348334                     0.099976    1192.784382
# std        2.757704                     0.304591    1173.160069
# min        0.000000                     0.000000       0.000000
# 25%        0.000000                     0.000000     503.000000
# 50%        1.000000                     0.000000    1106.000000
# 75%        4.000000                     0.000000    1770.000000
# max       21.000000                     2.000000  182764.000000
#
#        saturated-fat_100g   sugars_100g  proteins_100g     salt_100g  \
# count        42456.000000  42586.000000   44024.000000  42616.000000
# mean             6.388728     15.455371       7.748537      1.311959
# std              8.970960     20.003384       7.929492      4.680861
# min              0.000000      0.000000       0.000000      0.000000
# 25%              0.600000      1.200000       1.900000      0.100000
# 50%              2.900000      5.500000       6.000000      0.680000
# 75%              9.300000     24.700000      10.200000      1.400000
# max            210.000000    105.000000     100.000000    211.000000
#
#         sodium_100g  nutrition-score-fr_100g
# count  42615.000000             41690.000000
# mean       0.516530                11.102279
# std        1.842803                 7.790992
# min        0.000000                 0.000000
# 25%        0.039370                 4.000000
# 50%        0.267716                11.000000
# 75%        0.551181                17.000000
# max       83.000000                40.000000

# %%
## afin de détecter d'éventuelles valeurs aberrantes, 
## nous traçons les boxplot pour  chaque valeurs nutritives ainsi que les nutriscore

## boxplot
from matplotlib import rcParams

rcParams['figure.figsize'] = 20,10
g=sns.boxplot(data=df[nutriment_cols])
g.set_yscale("log")

## présence de plusieurs valeurs aberrantes sauf pour le nutriscore

# %%
## suppression de toutes les valeurs nutririonnelles supérieures à 100g
##df[df[nutriment_cols]>100]
nutriment_cols=[i for i in df.columns.tolist() if i.endswith('_100g')]
for col in nutriment_cols:
    if col !='energy_100g':
        if len(df[df[col]>100]):
            #print(df[df[col]>100][col])
            df.drop(index=df[df[col]>100].index,inplace=True)

# %%
## identification et suppression des lignes dont le nutriscore dépasse 40 ou en dessous de -15
outliers_nutriscore=df[(df['nutrition-score-fr_100g']>40)|(df['nutrition-score-fr_100g']<-15)][['product_name','nutrition-score-fr_100g']]
print('outliers_nutriscore',outliers_nutriscore)
df.drop(index=outliers_nutriscore.index,inplace=True)
# Out:
# outliers_nutriscore Empty DataFrame
# Columns: [product_name, nutrition-score-fr_100g]
# Index: []

# %%
df.info() ##44475 lignes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44475 entries, 106 to 320763
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   product_name                 44475 non-null  object
#  1   categories                   31674 non-null  object
#  2   additives_n                  29372 non-null  float64
#  3   ingredients_from_palm_oil_n  29372 non-null  float64
#  4   nutrition_grade_fr           41685 non-null  object
#  5   energy_100g                  44236 non-null  float64
#  6   saturated-fat_100g           42451 non-null  float64
#  7   sugars_100g                  42580 non-null  float64
#  8   proteins_100g                44019 non-null  float64
#  9   salt_100g                    42611 non-null  float64
#  10  sodium_100g                  42610 non-null  float64
#  11  nutrition-score-fr_100g      41685 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 4.4+ MB

# %%
## fonction qui calcule les valeurs aberrantes sur un échantillon homogène de même catégorie
 # et   renvoit les noms des produits sous forme de liste
    
def find_outliers_by_category(col,data):

    Q3 = np.quantile(data[col], 0.75)
    Q1 = np.quantile(data[col], 0.25)
    IQR = Q3 - Q1   
    lower_range = Q1 - 1.5 * IQR
    upper_range = Q3 + 1.5 * IQR
    outlier_free_list = [x for x in data[col] if (
        (x > lower_range) & (x < upper_range))]
    outliers = data.loc[data[col].isin(outlier_free_list)]
    #print('outliers',outliers['product_name'])
    
    if len(outliers)>0:
        outliers=outliers['product_name'].values.tolist()
        return  list(map(lambda x: (x,col), outliers))
    else:
        return []

# %%
categories=[x for x in df['categories'].unique() if ~pd.isna(x)]

# %%
## prends 11 minutes
outliers_products=[]
for category in categories:
    for col in nutriment_cols:
        data=df[df['categories']==category][[col,'product_name','categories']]
        if len(data)>0:
            outliers_products=outliers_products+find_outliers_by_category(col,data)
        
        
        
print(outliers_products)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
## listes des produits avec la colonne pour laquelle y a une valeur aberrante
outliers_products
# Out:
# [('Pepsi, Nouveau goût !', 'energy_100g'),
#  ('Sowest Cola', 'energy_100g'),
#  ('Montania Cola', 'energy_100g'),
#  ('Liger Cola', 'energy_100g'),
#  ('Soda aux extraits végétaux Cola', 'energy_100g'),
#  ('Quebec Soda', 'energy_100g'),
#  ('Fizz Cola Bio', 'energy_100g'),
#  ('Cola classic', 'energy_100g'),
#  ('Cola Classic', 'energy_100g'),
#  ('Pure Sensation Cola', 'energy_100g'),
#  ('Pure Sensation Cola Cherry', 'energy_100g'),
#  ('Planet Cola', 'energy_100g'),
#  ('Planet Cola Cherry', 'energy_100g'),
#  ('Planet cola', 'energy_100g'),
#  ('Limonade au cola pur sucre', 'energy_100g'),
#  ('Coca-cola 1,5 l', 'energy_100g'),
#  ('Fentimans Curiosity Cola 125ML', 'energy_100g'),
#  ('Coca-cola cherry', 'energy_100g'),
#  ('Coca-cola vanille', 'energy_100g'),
#  ('Coca Cola Jeux Olympiques de Londres 2012', 'energy_100g'),
#  ('Coca Cola Cherry', 'energy_100g'),
#  ('Coca Cola sans caféine', 'energy_100g'),
#  ('All Buter Belgian White Chocolate Chunk Cookies', 'energy_100g'),
#  ('Stem Ginger Dunkers', 'energy_100g'),
#  ('Cookies Pocket nougatine & pépites de chocolat', 'energy_100g'),
#  ('Cookies Noix de précan & pépites de chocolat', 'energy_100g'),
#  ('Cookies maxi', 'energy_100g'),
#  ('Cookies moelleux', 'energy_100g'),
#  ('Cookies aux pépites de chocolat ', 'energy_100g'),
#  ('Cookie extra moelleux', 'energy_100g'),
#  ('Cookies Pomme Caramel', 'energy_100g'),
#  ('Original cookies', 'energy_100g'),
#  ('Luxury Cookies Double Chocolate Cadbury', 'energy_100g'),
#  ('Organiser cookies', 'energy_100g'),
#  ('All Buter Belgian White Chocolate Chunk Cookies', 'saturated-fat_100g'),
#  ('Stem Ginger Cookies', 'saturated-fat_100g'),
#  ('Stem Ginger Dunkers', 'saturated-fat_100g'),
#  ('Cookies Pocket nougatine & pépites de chocolat', 'saturated-fat_100g'),
#  ('Cookies Noix de précan & pépites de chocolat', 'saturated-fat_100g'),
#  ('Cookies maxi', 'saturated-fat_100g'),
#  ('Cookies moelleux', 'saturated-fat_100g'),
#  ('Cookies aux pépites de chocolat ', 'saturated-fat_100g'),
#  ('Cookie extra moelleux', 'saturated-fat_100g'),
#  ('Cookies Pomme Caramel', 'saturated-fat_100g'),
#  ('Original cookies', 'saturated-fat_100g'),
#  ('Luxury Cookies Double Chocolate Cadbury', 'saturated-fat_100g'),
#  ('Organiser cookies', 'saturated-fat_100g'),
#  ('All Buter Belgian White Chocolate Chunk Cookies', 'sugars_100g'),
#  ('Stem Ginger Cookies', 'sugars_100g'),
#  ('Stem Ginger Dunkers', 'sugars_100g'),
#  ('Cookies Pocket nougatine & pépites de chocolat', 'sugars_100g'),
#  ('Cookies Noix de précan & pépites de chocolat', 'sugars_100g'),
#  ('Cookies maxi', 'sugars_100g'),
#  ('Cookies moelleux', 'sugars_100g'),
#  ('Cookie extra moelleux', 'sugars_100g'),
#  ('Cookies Pomme Caramel', 'sugars_100g'),
#  ('Original cookies', 'sugars_100g'),
#  ('Luxury Cookies Double Chocolate Cadbury', 'sugars_100g'),
#  ('All Buter Belgian White Chocolate Chunk Cookies', 'proteins_100g'),
#  ('Stem Ginger Cookies', 'proteins_100g'),
#  ('Stem Ginger Dunkers', 'proteins_100g'),
#  ('Cookies Pocket nougatine & pépites de chocolat', 'proteins_100g'),
#  ('Cookies maxi', 'proteins_100g'),
#  ('Cookies moelleux', 'proteins_100g'),
#  ('Cookies aux pépites de chocolat ', 'proteins_100g'),
#  ('Cookie extra moelleux', 'proteins_100g'),
#  ('Cookies Pomme Caramel', 'proteins_100g'),
#  ('Original cookies', 'proteins_100g'),
#  ('Luxury Cookies Double Chocolate Cadbury', 'proteins_100g'),
#  ('All Buter Belgian White Chocolate Chunk Cookies', 'salt_100g'),
#  ('Stem Ginger Cookies', 'salt_100g'),
#  ('Stem Ginger Dunkers', 'salt_100g'),
#  ('Cookies Pocket nougatine & pépites de chocolat', 'salt_100g'),
#  ('Cookies Noix de précan & pépites de chocolat', 'salt_100g'),
#  ('Cookies maxi', 'salt_100g'),
#  ('Cookies moelleux', 'salt_100g'),
#  ('Cookies aux pépites de chocolat ', 'salt_100g'),
#  ('Cookie extra moelleux', 'salt_100g'),
#  ('Cookies Pomme Caramel', 'salt_100g'),
#  ('Original cookies', 'salt_100g'),
#  ('Luxury Cookies Double Chocolate Cadbury', 'salt_100g'),
#  ('Organiser cookies', 'salt_100g'),
#  ('All Buter Belgian White Chocolate Chunk Cookies', 'sodium_100g'),
#  ('Stem Ginger Cookies', 'sodium_100g'),
#  ('Stem Ginger Dunkers', 'sodium_100g'),
#  ('Cookies Pocket nougatine & pépites de chocolat', 'sodium_100g'),
#  ('Cookies Noix de précan & pépites de chocolat', 'sodium_100g'),
#  ('Cookies maxi', 'sodium_100g'),
#  ('Cookies moelleux', 'sodium_100g'),
#  ('Cookies aux pépites de chocolat ', 'sodium_100g'),
#  ('Cookie extra moelleux', 'sodium_100g'),
#  ('Cookies Pomme Caramel', 'sodium_100g'),
#  ('Original cookies', 'sodium_100g'),
#  ('Luxury Cookies Double Chocolate Cadbury', 'sodium_100g'),
#  ('Organiser cookies', 'sodium_100g'),
#  ('All Buter Belgian White Chocolate Chunk Cookies',
#   'nutrition-score-fr_100g'),
#  ('Stem Ginger Cookies', 'nutrition-score-fr_100g'),
#  ('Stem Ginger Dunkers', 'nutrition-score-fr_100g'),
#  ('Cookies Pocket nougatine & pépites de chocolat', 'nutrition-score-fr_100g'),
#  ('Cookies Noix de précan & pépites de chocolat', 'nutrition-score-fr_100g'),
#  ('Cookies maxi', 'nutrition-score-fr_100g'),
#  ('Cookies moelleux', 'nutrition-score-fr_100g'),
#  ('Cookie extra moelleux', 'nutrition-score-fr_100g'),
#  ('Cookies Pomme Caramel', 'nutrition-score-fr_100g'),
#  ('Original cookies', 'nutrition-score-fr_100g'),
#  ('Luxury Cookies Double Chocolate Cadbury', 'nutrition-score-fr_100g'),
#  ('Organiser cookies', 'nutrition-score-fr_100g'),
#  ('Aloe Vera Grape & Apple Juice', 'energy_100g'),
#  ('Oasis multifruit', 'energy_100g'),
#  ('Planteur sans alcool', 'energy_100g'),
#  ('Fruits gourmands pomme-kiwi', 'energy_100g'),
#  ('Jus de mangue', 'energy_100g'),
#  ('Fun Pocket Saveur Pomme Cassis', 'energy_100g'),
#  ('Sunny Delight Boisson orange fraise', 'energy_100g'),
#  ('Cranberry', 'energy_100g'),
#  ('Tamek Orange Carrot Lemon Drink', 'energy_100g'),
#  ('Aloe Vera Grape & Apple Juice', 'saturated-fat_100g'),
#  ('Oasis multifruit', 'saturated-fat_100g'),
#  ('Planteur sans alcool', 'saturated-fat_100g'),
#  ('Fruits gourmands pomme-kiwi', 'saturated-fat_100g'),
#  ('Jus de mangue', 'saturated-fat_100g'),
#  ('Saveur Tropical', 'saturated-fat_100g'),
#  ('Sunny Delight Boisson orange fraise', 'saturated-fat_100g'),
#  ('Cranberry', 'saturated-fat_100g'),
#  ('Tamek Orange Carrot Lemon Drink', 'saturated-fat_100g'),
#  ('Aloe Vera Grape & Apple Juice', 'sugars_100g'),
#  ('Oasis multifruit', 'sugars_100g'),
#  ('Planteur sans alcool', 'sugars_100g'),
#  ('Fruits gourmands pomme-kiwi', 'sugars_100g'),
#  ('Jus de mangue', 'sugars_100g'),
#  ('Saveur Tropical', 'sugars_100g'),
#  ('Fun Pocket Saveur Pomme Cassis', 'sugars_100g'),
#  ('Sunny Delight Boisson orange fraise', 'sugars_100g'),
#  ('Cranberry', 'sugars_100g'),
#  ('Tamek Orange Carrot Lemon Drink', 'sugars_100g'),
#  ('Aloe Vera Grape & Apple Juice', 'proteins_100g'),
#  ('Oasis multifruit', 'proteins_100g'),
#  ('Planteur sans alcool', 'proteins_100g'),
#  ('Fruits gourmands pomme-kiwi', 'proteins_100g'),
#  ('Jus de mangue', 'proteins_100g'),
#  ('Saveur Tropical', 'proteins_100g'),
#  ('Fun Pocket Saveur Pomme Cassis', 'proteins_100g'),
#  ('Sunny Delight Boisson orange fraise', 'proteins_100g'),
#  ('Cranberry', 'proteins_100g'),
#  ('Tamek Orange Carrot Lemon Drink', 'proteins_100g'),
#  ('Oasis multifruit', 'salt_100g'),
#  ('Planteur sans alcool', 'salt_100g'),
#  ('Fruits gourmands pomme-kiwi', 'salt_100g'),
#  ('Jus de mangue', 'salt_100g'),
#  ('Saveur Tropical', 'salt_100g'),
#  ('Fun Pocket Saveur Pomme Cassis', 'salt_100g'),
#  ('Cranberry', 'salt_100g'),
#  ('Tamek Orange Carrot Lemon Drink', 'salt_100g'),
#  ('Oasis multifruit', 'sodium_100g'),
#  ('Planteur sans alcool', 'sodium_100g'),
#  ('Fruits gourmands pomme-kiwi', 'sodium_100g'),
#  ('Jus de mangue', 'sodium_100g'),
#  ('Saveur Tropical', 'sodium_100g'),
#  ('Fun Pocket Saveur Pomme Cassis', 'sodium_100g'),
#  ('Cranberry', 'sodium_100g'),
#  ('Tamek Orange Carrot Lemon Drink', 'sodium_100g'),
#  ('Aloe Vera Grape & Apple Juice', 'nutrition-score-fr_100g'),
#  ('Oasis multifruit', 'nutrition-score-fr_100g'),
#  ('Planteur sans alcool', 'nutrition-score-fr_100g'),
#  ('Fruits gourmands pomme-kiwi', 'nutrition-score-fr_100g'),
#  ('Jus de mangue', 'nutrition-score-fr_100g'),
#  ('Saveur Tropical', 'nutrition-score-fr_100g'),
#  ('Fun Pocket Saveur Pomme Cassis', 'nutrition-score-fr_100g'),
#  ('Sunny Delight Boisson orange fraise', 'nutrition-score-fr_100g'),
#  ('Cranberry', 'nutrition-score-fr_100g'),
#  ('Tamek Orange Carrot Lemon Drink', 'nutrition-score-fr_100g'),
#  ('Mild Cheddar with Onions & Chives', 'energy_100g'),
#  ('Cheddar au lait pasteurisé', 'energy_100g'),
#  ('Mild Cheddar with Onions & Chives', 'saturated-fat_100g'),
#  ('Cheddar au lait pasteurisé', 'saturated-fat_100g'),
#  ('Mild Cheddar with Onions & Chives', 'sugars_100g'),
#  ('Cheddar au lait pasteurisé', 'sugars_100g'),
#  ('Mild Cheddar with Onions & Chives', 'proteins_100g'),
#  ('Cheddar au lait pasteurisé', 'proteins_100g'),
#  ('Mild Cheddar with Onions & Chives', 'salt_100g'),
#  ('Cheddar au lait pasteurisé', 'salt_100g'),
#  ('Mild Cheddar with Onions & Chives', 'sodium_100g'),
#  ('Cheddar au lait pasteurisé', 'sodium_100g'),
#  ('Mild Cheddar with Onions & Chives', 'nutrition-score-fr_100g'),
#  ('Cheddar au lait pasteurisé', 'nutrition-score-fr_100g'),
#  ('Balsamic vinegar of Modena', 'energy_100g'),
#  ('Vinaigre balsamique de Modena', 'energy_100g'),
#  ('Balsamic vinegar of Modena', 'sugars_100g'),
#  ('Vinaigre balsamique de Modena', 'sugars_100g'),
#  ('Balsamic vinegar of Modena', 'salt_100g'),
#  ('Vinaigre balsamique de Modena', 'salt_100g'),
#  ('Balsamic vinegar of Modena', 'sodium_100g'),
#  ('Vinaigre balsamique de Modena', 'sodium_100g'),
#  ('Fresh Drinking Coconut', 'energy_100g'),
#  ('Soursop Juice', 'energy_100g'),
#  ('Boisson Epeaute Riz Avoine Noisette', 'energy_100g'),
#  ('Lait coco amande', 'energy_100g'),
#  ('Soya drink natural ', 'energy_100g'),
#  ('Organic Energiser', 'energy_100g'),
#  ('Refreshing drink with rooibos extract and peach flavour', 'energy_100g'),
#  ('Water & What U Need Watermelon & Lychee', 'energy_100g'),
#  ('Boisson amande', 'energy_100g'),
#  ('Riznoisette', 'energy_100g'),
#  ('Aloe vera king (Aloe vera drink)', 'energy_100g'),
#  ('Aloe Vera Organic', 'energy_100g'),
#  ('Boisson Aux Graines De Basilic Aromes Passion', 'energy_100g'),
#  ('Boisson au chrysanthème', 'energy_100g'),
#  ("Yeo's Soy Bean Drink", 'energy_100g'),
#  ('Fresh Drinking Coconut', 'saturated-fat_100g'),
#  ('Soursop Juice', 'saturated-fat_100g'),
#  ('Céréales et chicorée bio', 'saturated-fat_100g'),
#  ('Boisson Epeaute Riz Avoine Noisette', 'saturated-fat_100g'),
#  ('Lait coco amande', 'saturated-fat_100g'),
#  ('Soya drink natural ', 'saturated-fat_100g'),
#  ('Organic Energiser', 'saturated-fat_100g'),
#  ('Refreshing drink with rooibos extract and peach flavour',
#   'saturated-fat_100g'),
#  ('Boisson amande', 'saturated-fat_100g'),
#  ('Riznoisette', 'saturated-fat_100g'),
#  ('Aloe vera king (Aloe vera drink)', 'saturated-fat_100g'),
#  ('Aloe Vera Organic', 'saturated-fat_100g'),
#  ('Boisson Aux Graines De Basilic Aromes Passion', 'saturated-fat_100g'),
#  ('Boisson au chrysanthème', 'saturated-fat_100g'),
#  ("Yeo's Soy Bean Drink", 'saturated-fat_100g'),
#  ('Fresh Drinking Coconut', 'sugars_100g'),
#  ('Soursop Juice', 'sugars_100g'),
#  ('Céréales et chicorée bio', 'sugars_100g'),
#  ('Boisson Epeaute Riz Avoine Noisette', 'sugars_100g'),
#  ('Lait coco amande', 'sugars_100g'),
#  ('Soya drink natural ', 'sugars_100g'),
#  ('Organic Energiser', 'sugars_100g'),
#  ('Refreshing drink with rooibos extract and peach flavour', 'sugars_100g'),
#  ('Water & What U Need Watermelon & Lychee', 'sugars_100g'),
#  ('Boisson amande', 'sugars_100g'),
#  ('Riznoisette', 'sugars_100g'),
#  ('Aloe vera king (Aloe vera drink)', 'sugars_100g'),
#  ('Aloe Vera Organic', 'sugars_100g'),
#  ('Boisson Aux Graines De Basilic Aromes Passion', 'sugars_100g'),
#  ('Boisson au chrysanthème', 'sugars_100g'),
#  ("Yeo's Soy Bean Drink", 'sugars_100g'),
#  ('Fresh Drinking Coconut', 'proteins_100g'),
#  ('Soursop Juice', 'proteins_100g'),
#  ('Boisson Epeaute Riz Avoine Noisette', 'proteins_100g'),
#  ('Lait coco amande', 'proteins_100g'),
#  ('Organic Energiser', 'proteins_100g'),
#  ('Refreshing drink with rooibos extract and peach flavour', 'proteins_100g'),
#  ('Water & What U Need Watermelon & Lychee', 'proteins_100g'),
#  ('Boisson amande', 'proteins_100g'),
#  ('Riznoisette', 'proteins_100g'),
#  ('Aloe vera king (Aloe vera drink)', 'proteins_100g'),
#  ('Aloe Vera Organic', 'proteins_100g'),
#  ('Boisson Aux Graines De Basilic Aromes Passion', 'proteins_100g'),
#  ('Boisson au chrysanthème', 'proteins_100g'),
#  ("Yeo's Soy Bean Drink", 'proteins_100g'),
#  ('Fresh Drinking Coconut', 'salt_100g'),
#  ('Soursop Juice', 'salt_100g'),
#  ('Boisson bio au soja saveur chocolat', 'salt_100g'),
#  ('Boisson Epeaute Riz Avoine Noisette', 'salt_100g'),
#  ('Lait coco amande', 'salt_100g'),
#  ('Soya drink natural ', 'salt_100g'),
#  ('Organic Energiser', 'salt_100g'),
#  ('Refreshing drink with rooibos extract and peach flavour', 'salt_100g'),
#  ('Boisson amande', 'salt_100g'),
#  ('Riznoisette', 'salt_100g'),
#  ('Aloe vera king (Aloe vera drink)', 'salt_100g'),
#  ('Aloe Vera Organic', 'salt_100g'),
#  ('Boisson au chrysanthème', 'salt_100g'),
#  ("Yeo's Soy Bean Drink", 'salt_100g'),
#  ('Fresh Drinking Coconut', 'sodium_100g'),
#  ('Soursop Juice', 'sodium_100g'),
#  ('Boisson bio au soja saveur chocolat', 'sodium_100g'),
#  ('Boisson Epeaute Riz Avoine Noisette', 'sodium_100g'),
#  ('Lait coco amande', 'sodium_100g'),
#  ('Soya drink natural ', 'sodium_100g'),
#  ('Organic Energiser', 'sodium_100g'),
#  ('Refreshing drink with rooibos extract and peach flavour', 'sodium_100g'),
#  ('Boisson amande', 'sodium_100g'),
#  ('Riznoisette', 'sodium_100g'),
#  ('Aloe vera king (Aloe vera drink)', 'sodium_100g'),
#  ('Aloe Vera Organic', 'sodium_100g'),
#  ('Boisson au chrysanthème', 'sodium_100g'),
#  ("Yeo's Soy Bean Drink", 'sodium_100g'),
#  ('Fresh Drinking Coconut', 'nutrition-score-fr_100g'),
#  ('Soursop Juice', 'nutrition-score-fr_100g'),
#  ('Céréales et chicorée bio', 'nutrition-score-fr_100g'),
#  ('Boisson bio au soja saveur chocolat', 'nutrition-score-fr_100g'),
#  ('Boisson Epeaute Riz Avoine Noisette', 'nutrition-score-fr_100g'),
#  ('Lait coco amande', 'nutrition-score-fr_100g'),
#  ('Soya drink natural ', 'nutrition-score-fr_100g'),
#  ('Organic Energiser', 'nutrition-score-fr_100g'),
#  ('Refreshing drink with rooibos extract and peach flavour',
#   'nutrition-score-fr_100g'),
#  ('Water & What U Need Watermelon & Lychee', 'nutrition-score-fr_100g'),
#  ('Boisson amande', 'nutrition-score-fr_100g'),
#  ('Riznoisette', 'nutrition-score-fr_100g'),
#  ('Aloe vera king (Aloe vera drink)', 'nutrition-score-fr_100g'),
#  ('Aloe Vera Organic', 'nutrition-score-fr_100g'),
#  ('Boisson au chrysanthème', 'nutrition-score-fr_100g'),
#  ("Yeo's Soy Bean Drink", 'nutrition-score-fr_100g'),
#  ('Ginger candy', 'energy_100g'),
#  ('Tic Tac fresh mint', 'energy_100g'),
#  ('Tyrkisk Peber', 'energy_100g'),
#  ('Tic Tac Intense Mint', 'energy_100g'),
#  ('Ginger candy', 'saturated-fat_100g'),
#  ('Tic Tac fresh mint', 'saturated-fat_100g'),
#  ('Tyrkisk Peber', 'saturated-fat_100g'),
#  ('Tic Tac Intense Mint', 'saturated-fat_100g'),
#  ('Ginger candy', 'sugars_100g'),
#  ('Tic Tac fresh mint', 'sugars_100g'),
#  ('Tyrkisk Peber', 'sugars_100g'),
#  ('Tic Tac Intense Mint', 'sugars_100g'),
#  ('Ginger candy', 'proteins_100g'),
#  ('Tic Tac fresh mint', 'proteins_100g'),
#  ('Tic Tac Intense Mint', 'proteins_100g'),
#  ('Ginger candy', 'salt_100g'),
#  ('Tic Tac fresh mint', 'salt_100g'),
#  ('Tic Tac Intense Mint', 'salt_100g'),
#  ('Ginger candy', 'sodium_100g'),
#  ('Tic Tac fresh mint', 'sodium_100g'),
#  ('Tic Tac Intense Mint', 'sodium_100g'),
#  ('Ginger candy', 'nutrition-score-fr_100g'),
#  ('Tic Tac fresh mint', 'nutrition-score-fr_100g'),
#  ('Tic Tac Intense Mint', 'nutrition-score-fr_100g'),
#  ('Reduced Fat Belgian Chocolate Chunk Cookies', 'energy_100g'),
#  ('Chocolate Chunk Dark Double Chocolate Crispy Cookies', 'energy_100g'),
#  ('Chocolate Chunk Milk Chocolate Macadamia Crispy Cookies', 'energy_100g'),
#  ('Chocolate Chunk White Chocolate Macadamia Crispy Cookies', 'energy_100g'),
#  ('Soft Baker chocolate chunk', 'energy_100g'),
#  ('Shortbread Cookies', 'energy_100g'),
#  ('Cookies Caramel au beurre salé aux gros éclats de chocolat', 'energy_100g'),
#  ('Cookie aux pépites de chocolat', 'energy_100g'),
#  ('Cookies à La Nougatine et Pépites De Chocolat', 'energy_100g'),
#  ('Petits Cookies Pépites de Chocolat', 'energy_100g'),
#  ('Cookies Fruits Rouges', 'energy_100g'),
#  ('Les cookies de la Mère Poulard', 'energy_100g'),
#  ('Cookies choco', 'energy_100g'),
#  ('Original cookies Chocolat Blanc Cranberries', 'energy_100g'),
#  ('Cookies aux Pépites de Chocolat (Mous)', 'energy_100g'),
#  ('Cookies chocolat ', 'energy_100g'),
#  ('Le Cookie des Rois', 'energy_100g'),
#  ('Mini Granola', 'energy_100g'),
#  ('Reduced Fat Belgian Chocolate Chunk Cookies', 'proteins_100g'),
#  ('Chocolate Chunk Dark Double Chocolate Crispy Cookies', 'proteins_100g'),
#  ('Chocolate Chunk Milk Chocolate Macadamia Crispy Cookies', 'proteins_100g'),
#  ('Chocolate Chunk White Chocolate Macadamia Crispy Cookies', 'proteins_100g'),
#  ('Soft Baker chocolate chunk', 'proteins_100g'),
#  ('Shortbread Cookies', 'proteins_100g'),
#  ('Mini cookies noix de pécan millet', 'proteins_100g'),
#  ('Cookies Caramel au beurre salé aux gros éclats de chocolat',
#   'proteins_100g'),
#  ('Cookie aux pépites de chocolat', 'proteins_100g'),
#  ('Cookies à La Nougatine et Pépites De Chocolat', 'proteins_100g'),
#  ('Petits Cookies Pépites de Chocolat', 'proteins_100g'),
#  ('Cookies Fruits Rouges', 'proteins_100g'),
#  ('Les cookies de la Mère Poulard', 'proteins_100g'),
#  ('Cookies choco', 'proteins_100g'),
#  ('Original cookies Chocolat Blanc Cranberries', 'proteins_100g'),
#  ('Cookies aux Pépites de Chocolat (Mous)', 'proteins_100g'),
#  ('Cookies chocolat ', 'proteins_100g'),
#  ('Le Cookie des Rois', 'proteins_100g'),
#  ('Mini Granola', 'proteins_100g'),
#  ('Chocolate Chunk Crispy Cookies - Dark Chocolate Pecan', 'energy_100g'),
#  ('Magic Cookies Coeur Fondant', 'energy_100g'),
#  ('Cookies éclats de chocolat', 'energy_100g'),
#  ('Maxi Cookies Gros Chunks de Chocolat Noir et Cacao', 'energy_100g'),
#  ('Tronches de Cake - Cookies Céréales Soufflées Nappés Choco', 'energy_100g'),
#  ('12 Cookies Tout Chocolat', 'energy_100g'),
#  ('Cookies aux Pépites de Chocolat Noir ', 'energy_100g'),
#  ('Cookies Chocolat', 'energy_100g'),
#  ('Maxi Cookies Pépites de Chocolat Noir', 'energy_100g'),
#  ('Cookies double chocolat lait & noir', 'energy_100g'),
#  ('Cookies Pocket Chocolat & Pépites de Chocolat', 'energy_100g'),
#  ('Cookies chocolat pépites de chocolat pur beurre', 'energy_100g'),
#  ('Cookies Tout Choco', 'energy_100g'),
#  ('Cookies Quinoa Chocolat', 'energy_100g'),
#  ('Cookies Tout choco - Chocolat Noir et Pépites de Chocolat', 'energy_100g'),
#  ('Cookies bio au chocolat noir', 'energy_100g'),
#  ('Cookies pépites de chocolat', 'energy_100g'),
#  ('Cookies au chocolat', 'energy_100g'),
#  ('Cookies chocolat & pépites de chocolat', 'energy_100g'),
#  ('Cookies aux Pépites de Chocolat', 'energy_100g'),
#  ('Cookies Brownies', 'energy_100g'),
#  ('Cookies goût chocolat', 'energy_100g'),
#  ('cookies goût chocolat', 'energy_100g'),
#  ('Cookies chocolat', 'energy_100g'),
#  ('Chocolate Chunk Crispy Cookies - Dark Chocolate Pecan', 'proteins_100g'),
#  ('Magic Cookies Coeur Fondant', 'proteins_100g'),
#  ('Cookies éclats de chocolat', 'proteins_100g'),
#  ('Maxi Cookies Gros Chunks de Chocolat Noir et Cacao', 'proteins_100g'),
#  ('Tronches de Cake - Cookies Céréales Soufflées Nappés Choco',
#   'proteins_100g'),
#  ('12 Cookies Tout Chocolat', 'proteins_100g'),
#  ('Cookies aux Pépites de Chocolat Noir ', 'proteins_100g'),
#  ('Cookies Chocolat', 'proteins_100g'),
#  ('Maxi Cookies Pépites de Chocolat Noir', 'proteins_100g'),
#  ('Cookies double chocolat lait & noir', 'proteins_100g'),
#  ('Cookies Pocket Chocolat & Pépites de Chocolat', 'proteins_100g'),
#  ('Cookies chocolat pépites de chocolat pur beurre', 'proteins_100g'),
#  ('Cookies Tout Choco', 'proteins_100g'),
#  ('Cookies Quinoa Chocolat', 'proteins_100g'),
#  ('Cookies Tout choco - Chocolat Noir et Pépites de Chocolat',
#   'proteins_100g'),
#  ('Cookies bio au chocolat noir', 'proteins_100g'),
#  ('Cookies pépites de chocolat', 'proteins_100g'),
#  ('Cookies au chocolat', 'proteins_100g'),
#  ('Cookies chocolat & pépites de chocolat', 'proteins_100g'),
#  ('Cookies aux Pépites de Chocolat', 'proteins_100g'),
#  ('Cookies Brownies', 'proteins_100g'),
#  ('Cookies goût chocolat', 'proteins_100g'),
#  ('cookies goût chocolat', 'proteins_100g'),
#  ('Cookies chocolat', 'proteins_100g'),
#  ('Mini cookies cœur fondant, chocolat au lait et noisettes', 'proteins_100g'),
#  ('Cookies tendres Chocolat', 'proteins_100g'),
#  ('Soft Baked Chocolate Chunk Dark Chocolat Brownie', 'energy_100g'),
#  ('Maxi Cookies Bio Chocolat au lait et cranberries', 'energy_100g'),
#  ('Soft Baked Chocolate Chunk Dark Chocolat Brownie', 'saturated-fat_100g'),
#  ('Maxi Cookies Bio Chocolat au lait et cranberries', 'saturated-fat_100g'),
#  ('Soft Baked Chocolate Chunk Dark Chocolat Brownie', 'sugars_100g'),
#  ('Maxi Cookies Bio Chocolat au lait et cranberries', 'sugars_100g'),
#  ('Soft Baked Chocolate Chunk Dark Chocolat Brownie', 'proteins_100g'),
#  ('Maxi Cookies Bio Chocolat au lait et cranberries', 'proteins_100g'),
#  ('Soft Baked Chocolate Chunk Dark Chocolat Brownie', 'salt_100g'),
#  ('Maxi Cookies Bio Chocolat au lait et cranberries', 'salt_100g'),
#  ('Soft Baked Chocolate Chunk Dark Chocolat Brownie', 'sodium_100g'),
#  ('Maxi Cookies Bio Chocolat au lait et cranberries', 'sodium_100g'),
#  ('Goldfish Cheddar', 'energy_100g'),
#  ('Snack-Mix', 'energy_100g'),
#  ('Flûtes Salées', 'energy_100g'),
#  ('Croustillants Cacahuète', 'energy_100g'),
#  ("Witti's à l'emmental", 'energy_100g'),
#  ('Flûtes Fromage', 'energy_100g'),
#  ('Crackers Tomate Mozzarella', 'energy_100g'),
#  ('Tuc Sésame', 'energy_100g'),
#  ('Grissini Graines de Sésame', 'energy_100g'),
#  ('Monaco au fromage de Hollande', 'energy_100g'),
#  ('Belin réception', 'energy_100g'),
#  ("Croc'Balls", 'energy_100g'),
#  ('Best of', 'energy_100g'),
#  ('Triangolini au sésame', 'energy_100g'),
#  ('Minizza tomate', 'energy_100g'),
#  ('Snacky extra-fins', 'energy_100g'),
#  ('Crêpes Fourrées Chèvre & Romarin', 'energy_100g'),
#  ('Apéro Cracks Mix Salé + Emmental', 'energy_100g'),
#  ("P'tits Toasts goût Tomate Provençale", 'energy_100g'),
#  ("3D's bugles goût bacon", 'energy_100g'),
#  ('Twinuts goût Bacon (lot de 2, +10% gratuit)', 'energy_100g'),
#  ('Twinuts saveur Mexicaine (lot de 2, +10% gratuit)', 'energy_100g'),
#  ('Twinuts goût Cheese', 'energy_100g'),
#  ("Apéro Cracks goût Huile d\\'olive et herbes", 'energy_100g'),
#  ('Apéros Cracks goût emmental', 'energy_100g'),
#  ('Apéro Cracks Maxi Craquants goût Nature', 'energy_100g'),
#  ('Apéro Cracks - Goût Tomate et oignons', 'energy_100g'),
#  ('Apéro Cracks - Goût Paprika', 'energy_100g'),
#  ('Apéro cracks goût Tomate Mozzarella et Basilic', 'energy_100g'),
#  ('Apéro Cracks Emmental', 'energy_100g'),
#  ('Apéro Cracks Fins & Fondants Mix Salé + Emmental', 'energy_100g'),
#  ('Crusty fromage, graines de courge', 'energy_100g'),
#  ('Assortiment cocktail', 'energy_100g'),
#  ('Flûtes Oignon Ciboulette', 'energy_100g'),
#  ('Palmiers salés fromage', 'energy_100g'),
#  ('Torsades feuilletées pur beurre', 'energy_100g'),
#  ('Crackers emmental et graines de courge', 'energy_100g'),
#  ('Petites crêpes fourrées au roquefort', 'energy_100g'),
#  ('Snack Poppé à Base de Soja & Pomme de Terre Saveur Tomates & Herbes',
#   'energy_100g'),
#  ('snack poppé [à base de soja & pomme de terre] saveur sel & poivre',
#   'energy_100g'),
#  ('Crackers allégés saveur Tomate épicée', 'energy_100g'),
#  ("Cracker's salés", 'energy_100g'),
#  ('Crackers au Sésame & Pavot', 'energy_100g'),
#  ('Crackers goût Pizza', 'energy_100g'),
#  ("Pizz'Apéro saveur Pizza", 'energy_100g'),
#  ('Pizzas Tomate Emmental', 'energy_100g'),
#  ('Crackers goût quiche', 'energy_100g'),
#  ('Palmier Salés aux Olives ', 'energy_100g'),
#  ('crackers 3 graines', 'energy_100g'),
#  ('Assortiment crackers', 'energy_100g'),
#  ("Crackers goût fromage à l'emmental", 'energy_100g'),
#  ('Flûtes au fromage ', 'energy_100g'),
#  ('Palmiers saveur Olives noires', 'energy_100g'),
#  ('Crackers fromages & graines', 'energy_100g'),
#  ('Petits palmiers aux olives noires', 'energy_100g'),
#  ("P'tits crackers salés", 'energy_100g'),
#  ('Gaufrettes au sel de Guérande', 'energy_100g'),
#  ('Mini craquants Origan', 'energy_100g'),
#  ('Croustillants Extra Soufflé Epicé', 'energy_100g'),
#  ('Biscuits dans le monde de la ferme goût fromage', 'energy_100g'),
#  ('Chiffres nature', 'energy_100g'),
#  ("Sticks d'épeautre à l'huile d'olive", 'energy_100g'),
#  ('Crêpes Dentelle Fourrées au Roquefort', 'energy_100g'),
#  ('Mini torsades au beurre', 'energy_100g'),
#  ("Craquelins au son d'avoine sésame lin & cumin", 'energy_100g'),
#  ('Palmiers Salés au Beurre et aux Fromages (Gouda, Edam)', 'energy_100g'),
#  ("Triangles salés au beurre & au pimenr d'espelette", 'energy_100g'),
#  ("Crackers de Riz à l'huile d'olive", 'energy_100g'),
#  ('Crackers de Riz au Piment Doux', 'energy_100g'),
#  ('Les Crackers Nature', 'energy_100g'),
#  ('Sticks et Bretzels', 'energy_100g'),
#  ('Assortiment de biscuits salés', 'energy_100g'),
#  ('Mélange japonais ', 'energy_100g'),
#  ('Petites crêpes fourrées au Comté et saveur noix', 'energy_100g'),
#  ('Feuilletés aux fromages', 'energy_100g'),
#  ('Crackers au gouda', 'energy_100g'),
#  ('Coktail fruits', 'energy_100g'),
#  ('Crackers extra fin', 'energy_100g'),
#  ('Crackers au sésame & au pavot', 'energy_100g'),
#  ('Biscuits au fromage', 'energy_100g'),
#  ('Triangles feuilletés au cheddar et aux herbes de Provence', 'energy_100g'),
#  ('Crackers Olive Romarin', 'energy_100g'),
#  ('Mini-crackers emmental et graines de courge', 'energy_100g'),
#  ('Sticks apéritifs à l huile de tournesol ', 'energy_100g'),
#  ('Gressins Sésame', 'energy_100g'),
#  ('Crackers emmental', 'energy_100g'),
#  ('Crackers allégés saveur Crème Oignon', 'energy_100g'),
#  ('Crackers allégés saveur tomate épicée', 'energy_100g'),
#  ('Tokapi - Assortiment Crackers', 'energy_100g'),
#  ('Crackers 3 graines Tournesol - Sésame - Lin', 'energy_100g'),
#  ("Les ApériSablés pur beurre saveur Bacon / Bière du Ch'ti", 'energy_100g'),
#  ('pétales', 'energy_100g'),
#  ('croustillant goût fromage', 'energy_100g'),
#  ('Crêpes fourrées au comté', 'energy_100g'),
#  ('Crackers aux olives', 'energy_100g'),
#  ('Crackers assortis', 'energy_100g'),
#  ('Taralli aux olives noires', 'energy_100g'),
#  ('29 sablés ronds et bons au parmesan et graines de moutardes',
#   'energy_100g'),
#  ("Feuilletés apéritif à l'emmental et aux oignons", 'energy_100g'),
#  ('33 petits-beurre apéritifs au comté et au poivre', 'energy_100g'),
#  ('Gressins Tomate Origan', 'energy_100g'),
#  ('Petits crackers sans cuisson Olives & Oignon', 'energy_100g'),
#  ('Ticru sésame coco', 'energy_100g'),
#  ('Mélange de Biscuits - Recette Japonaise', 'energy_100g'),
#  ("Pizzini saveur tomate et huile d'olive 5%", 'energy_100g'),
#  ('Cracker sésame', 'energy_100g'),
#  ('Cream Crackers', 'energy_100g'),
#  ('Original Cheese Crackers', 'energy_100g'),
#  ('Original Potato Chips', 'energy_100g'),
#  ('Tuc goût bacon', 'energy_100g'),
#  ('Tuc original', 'energy_100g'),
#  ('Hula Hoops Bolognese', 'energy_100g'),
#  ('Crackers Cheese', 'energy_100g'),
#  ('Flûtes sesame', 'energy_100g'),
#  ('Feuilletýs', 'energy_100g'),
#  ('Mini-Twist Fromage', 'energy_100g'),
#  ("Tuc Break saveur Romarin Huile d'Olive", 'energy_100g'),
#  ('Tuc Break Original format pocket', 'energy_100g'),
#  ("Apéro Toasts à l'italienne", 'energy_100g'),
#  ('Monaco', 'energy_100g'),
#  ('Tuc goût Ail & Fines Herbes', 'energy_100g'),
#  ("Monaco à l'emmental", 'energy_100g'),
#  ('Tarallini con peperoncino', 'energy_100g'),
#  ('Taralli ai semi di Finocchio', 'energy_100g'),
#  ('Feuilletés aux olives noires', 'energy_100g'),
#  ('Crackers ondulés Fromage / Graines', 'energy_100g'),
#  ('Crackers sésame et pavot', 'energy_100g'),
#  ('Bâtons gouda', 'energy_100g'),
#  ('Asian Gourmet Chips Java', 'energy_100g'),
#  ('Black Pepper Crackers', 'energy_100g'),
#  ('Wasabi Crackers Mitsuba', 'energy_100g'),
#  ('Palmiers au beurre et au fromage', 'energy_100g'),
#  ('Crackers de riz au wasabi', 'energy_100g'),
#  ('Nems apéritifs aux crevettes piquantes', 'energy_100g'),
#  ("Nems apéritifs aux crevettes & à l'ail", 'energy_100g'),
#  ('Pistaches au piment doux', 'energy_100g'),
#  ('Pistaches sans sel ajouté', 'energy_100g'),
#  ('Pistaches crues  émondées', 'energy_100g'),
#  ('Pistaches au piment doux', 'proteins_100g'),
#  ('Pistaches sans sel ajouté', 'proteins_100g'),
#  ('Pistaches crues  émondées', 'proteins_100g'),
#  ('Pistaches XXL Poivre & Sel', 'energy_100g'),
#  ('Pistaches en coques grillées à sec', 'energy_100g'),
#  ('Pistaches XXL Poivre & Sel', 'saturated-fat_100g'),
#  ('Pistaches en coques grillées à sec', 'saturated-fat_100g'),
#  ('Pistaches XXL Poivre & Sel', 'sugars_100g'),
#  ('Pistaches en coques grillées à sec', 'sugars_100g'),
#  ('Pistaches XXL Poivre & Sel', 'proteins_100g'),
#  ('Pistaches en coques grillées à sec', 'proteins_100g'),
#  ('Pistaches XXL Poivre & Sel', 'salt_100g'),
#  ('Pistaches en coques grillées à sec', 'salt_100g'),
#  ('Pistaches XXL Poivre & Sel', 'sodium_100g'),
#  ('Pistaches en coques grillées à sec', 'sodium_100g'),
#  ('Pistaches XXL Poivre & Sel', 'nutrition-score-fr_100g'),
#  ('Pistaches en coques grillées à sec', 'nutrition-score-fr_100g'),
#  ('Pistaches XXL Grillées sans sel', 'energy_100g'),
#  ('Pistaches de Californe grillées à sec', 'energy_100g'),
#  ('Pistaches XXL Grillées sans sel', 'saturated-fat_100g'),
#  ('Pistaches de Californe grillées à sec', 'saturated-fat_100g'),
#  ('Pistaches XXL Grillées sans sel', 'sugars_100g'),
#  ('Pistaches de Californe grillées à sec', 'sugars_100g'),
#  ('Pistaches XXL Grillées sans sel', 'proteins_100g'),
#  ('Pistaches de Californe grillées à sec', 'proteins_100g'),
#  ('Vinaigre basalmique bio', 'energy_100g'),
#  ('Vinaigre basalmique de modene', 'energy_100g'),
#  ('vinaigre balsamique de Modène', 'energy_100g'),
#  ("Vinaigre Balsamique de Modène 6% d'acidité Bio", 'energy_100g'),
#  ('Aceto balsamico di modena', 'energy_100g'),
#  ('Vinaigre balsamique de Modène', 'energy_100g'),
#  ('Velours Balsamique', 'energy_100g'),
#  ('Spinach & Ricotta Stonebaked Hand Stretched Pizza', 'energy_100g'),
#  ('Pollo Arrabiata Parmigiano Wood Fired Pizza', 'energy_100g'),
#  ('Pizza Reine', 'energy_100g'),
#  ('Spinach & Ricotta Stonebaked Hand Stretched Pizza', 'saturated-fat_100g'),
#  ('Pollo Arrabiata Parmigiano Wood Fired Pizza', 'saturated-fat_100g'),
#  ('Pizza Reine', 'saturated-fat_100g'),
#  ('Spinach & Ricotta Stonebaked Hand Stretched Pizza', 'sugars_100g'),
#  ('Pollo Arrabiata Parmigiano Wood Fired Pizza', 'sugars_100g'),
#  ('Pizza Reine', 'sugars_100g'),
#  ('Spinach & Ricotta Stonebaked Hand Stretched Pizza', 'proteins_100g'),
#  ('Pollo Arrabiata Parmigiano Wood Fired Pizza', 'proteins_100g'),
#  ('Pizza Reine', 'proteins_100g'),
#  ('Spinach & Ricotta Stonebaked Hand Stretched Pizza', 'salt_100g'),
#  ('Pollo Arrabiata Parmigiano Wood Fired Pizza', 'salt_100g'),
#  ('Pizza Reine', 'salt_100g'),
#  ('Spinach & Ricotta Stonebaked Hand Stretched Pizza', 'sodium_100g'),
#  ('Pollo Arrabiata Parmigiano Wood Fired Pizza', 'sodium_100g'),
#  ('Pizza Reine', 'sodium_100g'),
#  ('Spinach & Ricotta Stonebaked Hand Stretched Pizza',
#   'nutrition-score-fr_100g'),
#  ('Pollo Arrabiata Parmigiano Wood Fired Pizza', 'nutrition-score-fr_100g'),
#  ('Pizza Reine', 'nutrition-score-fr_100g'),
#  ('Coconut Juice', 'energy_100g'),
#  ('coconut juice', 'energy_100g'),
#  ('Roasted Coconut Juice', 'energy_100g'),
#  ('Coconut Juice', 'saturated-fat_100g'),
#  ('coconut juice', 'saturated-fat_100g'),
#  ('Roasted Coconut Juice', 'saturated-fat_100g'),
#  ('Coconut Juice', 'sugars_100g'),
#  ('coconut juice', 'sugars_100g'),
#  ('Roasted Coconut Juice', 'sugars_100g'),
#  ('Coconut Juice', 'proteins_100g'),
#  ('coconut juice', 'proteins_100g'),
#  ('Roasted Coconut Juice', 'proteins_100g'),
#  ('Coconut Juice', 'salt_100g'),
#  ('coconut juice', 'salt_100g'),
#  ('Roasted Coconut Juice', 'salt_100g'),
#  ('Coconut Juice', 'sodium_100g'),
#  ('coconut juice', 'sodium_100g'),
#  ('Roasted Coconut Juice', 'sodium_100g'),
#  ('Coconut Juice', 'nutrition-score-fr_100g'),
#  ('coconut juice', 'nutrition-score-fr_100g'),
#  ('Roasted Coconut Juice', 'nutrition-score-fr_100g'),
#  ('Lychee drink', 'energy_100g'),
#  ('Citronnade - Menthe', 'energy_100g'),
#  ('Citron - Citron Vert', 'energy_100g'),
#  ('Tea & Red Fruits', 'energy_100g'),
#  ('Lychee drink', 'sugars_100g'),
#  ('Citronnade - Menthe', 'sugars_100g'),
#  ('Citron - Citron Vert', 'sugars_100g'),
#  ('Tea & Red Fruits', 'sugars_100g'),
#  ('Lychee drink', 'salt_100g'),
#  ('Citronnade - Menthe', 'salt_100g'),
#  ('Citron - Citron Vert', 'salt_100g'),
#  ('Tea & Red Fruits', 'salt_100g'),
#  ('Lychee drink', 'sodium_100g'),
#  ('Citronnade - Menthe', 'sodium_100g'),
#  ('Citron - Citron Vert', 'sodium_100g'),
#  ('Tea & Red Fruits', 'sodium_100g'),
#  ('Citronnade - Menthe', 'nutrition-score-fr_100g'),
#  ('Citron - Citron Vert', 'nutrition-score-fr_100g'),
#  ('Tea & Red Fruits', 'nutrition-score-fr_100g'),
#  ('Boisson a base de jus de lychee', 'energy_100g'),
#  ('Superfruits Grenade', 'energy_100g'),
#  ('Capital Fruits Rouges', 'energy_100g'),
#  ('Bio Cartoon Fraise', 'energy_100g'),
#  ('Guanabana', 'energy_100g'),
#  ('Boisson a base de jus de lychee', 'sugars_100g'),
#  ('Superfruits Grenade', 'sugars_100g'),
#  ('Capital Fruits Rouges', 'sugars_100g'),
#  ('Bio Cartoon Fraise', 'sugars_100g'),
#  ('Guanabana', 'sugars_100g'),
#  ('Boisson a base de jus de lychee', 'proteins_100g'),
#  ('Superfruits Grenade', 'proteins_100g'),
#  ('Capital Fruits Rouges', 'proteins_100g'),
#  ('Bio Cartoon Fraise', 'proteins_100g'),
#  ('Guanabana', 'proteins_100g'),
#  ('Boisson a base de jus de lychee', 'salt_100g'),
#  ('Superfruits Grenade', 'salt_100g'),
#  ('Capital Fruits Rouges', 'salt_100g'),
#  ('Bio Cartoon Fraise', 'salt_100g'),
#  ('Boisson a base de jus de lychee', 'sodium_100g'),
#  ('Superfruits Grenade', 'sodium_100g'),
#  ('Capital Fruits Rouges', 'sodium_100g'),
#  ('Bio Cartoon Fraise', 'sodium_100g'),
#  ('Boisson a base de jus de lychee', 'nutrition-score-fr_100g'),
#  ('Superfruits Grenade', 'nutrition-score-fr_100g'),
#  ('Capital Fruits Rouges', 'nutrition-score-fr_100g'),
#  ('Bio Cartoon Fraise', 'nutrition-score-fr_100g'),
#  ('Guanabana', 'nutrition-score-fr_100g'),
#  ('Boisson à base de jus de goyave', 'energy_100g'),
#  ('Boisson Passion', 'energy_100g'),
#  ('Boisson à base de Jus de Mangue', 'energy_100g'),
#  ('Mojito juice drink', 'energy_100g'),
#  ("Boisson au jus d'orange", 'energy_100g'),
#  ('Plein sud Orange', 'energy_100g'),
#  ('Apple & Prickly Pear Juice Drink', 'energy_100g'),
#  ('Jus de gwozey', 'energy_100g'),
#  ('Juicy agrumes ', 'energy_100g'),
#  ('Juicy pêche', 'energy_100g'),
#  ('Juicy Fruits Exotiques', 'energy_100g'),
#  ('Fruits & plantes Raisin - Rose', 'energy_100g'),
#  ('FruitMix Velouté', 'energy_100g'),
#  ('Fruit shoot Fruits rouges', 'energy_100g'),
#  ('Fruit shoot pomme banane', 'energy_100g'),
#  ('Fruit Shoot Pêche Mangue', 'energy_100g'),
#  ('Pulco Orangeade', 'energy_100g'),
#  ('Orange (7+1 gratuite)', 'energy_100g'),
#  ("P'tit Oasis Tropical", 'energy_100g'),
#  ('Pulco citron et menthe', 'energy_100g'),
#  ('Boisson pomme cassis framboise', 'energy_100g'),
#  ('Pomme-poire', 'energy_100g'),
#  ('Mon petit dej cereales  fraise banane', 'energy_100g'),
#  ('Fruits Exotiques', 'energy_100g'),
#  ('Boisson goût fraise-framboise', 'energy_100g'),
#  ("Cranberry Framboise à l'eau de source", 'energy_100g'),
#  ('Tropic', 'energy_100g'),
#  ('Superfruits Grenade sans sucres ajoutés', 'energy_100g'),
#  ("Tropical à l'eau de source", 'energy_100g'),
#  ('Pomme saveur Cannelle (EDITION LIMITEE)', 'energy_100g'),
#  ('Fruits de chez nous Kiwi du Lot et Garonne', 'energy_100g'),
#  ('Au Jus De Pêche', 'energy_100g'),
#  ('Boisson au jus de Cranberry', 'energy_100g'),
#  ("Fraise framboise à l'eau de source", 'energy_100g'),
#  ('Cranberry classic', 'energy_100g'),
#  ('Sex on the Beach', 'energy_100g'),
#  ('Le Verger Bio Multifruits', 'energy_100g'),
#  ('Boisson Tropicale', 'energy_100g'),
#  ('Boisson Prune de Cythère', 'energy_100g'),
#  ('Ananas Citron Vert Gingembre', 'energy_100g'),
#  ('Cocktail Ace', 'energy_100g'),
#  ('Jus de framboise', 'energy_100g'),
#  ('Jus de Litchi', 'energy_100g'),
#  ('Boissons aux fruits Ananas Orange Carotte', 'energy_100g'),
#  ('Boisson aux fruits saveur orange', 'energy_100g'),
#  ('Fraise framboise', 'energy_100g'),
#  ("Tropical, à l'eau de source", 'energy_100g'),
#  ("Pêche Abricot à l'Eau de Source", 'energy_100g'),
#  ('Pomme & Poire', 'energy_100g'),
#  ('Pomme cassis framboise', 'energy_100g'),
#  ('Eau De Source Armoatisée Fraise', 'energy_100g'),
#  ('Cranberry & Myrtille', 'energy_100g'),
#  ('Boisson pasteurisée aux Poires', 'energy_100g'),
#  ('Mojito (offre éco)', 'energy_100g'),
#  ('Citronnade A La Menthe (offre éco)', 'energy_100g'),
#  ('Sunny Delight', 'energy_100g'),
#  ('Tropico', 'energy_100g'),
#  ('Boisson aux fruits tropicaux (Pitaya, Acerola & Guarana)', 'energy_100g'),
#  ('Capri-Sun', 'energy_100g'),
#  ("Boisson à la Cranberry à base de jus concentré issu de l'agriculture biologique",
#   'energy_100g'),
#  ('Marina Cerise', 'energy_100g'),
#  ('Fruit Crush Pomme & Cassis', 'energy_100g'),
#  ('Jus Mango Multi-fruits', 'energy_100g'),
#  ('Bionade gingembre orange', 'energy_100g'),
#  ('Multifruit Juice Drink', 'energy_100g'),
#  ('Gratte-cul', 'energy_100g'),
#  ('Cranberry Classic Juice Drink', 'energy_100g'),
#  ('Juicy Water oranges & citrons', 'energy_100g'),
#  ('Juicy Water citrons et citrons verts', 'energy_100g'),
#  ('Lemon & Green Tea', 'energy_100g'),
#  ('Pomegranate & green tea', 'energy_100g'),
#  ('Super Fruit - Raisin, Acérola, Framboise Et Fraise', 'energy_100g'),
#  ('Jus Passion Fruit', 'energy_100g'),
#  ('Pure Infusion', 'energy_100g'),
#  ('Citrons Pressés', 'energy_100g'),
#  ('Oasis Pocket Cassis Framboise', 'energy_100g'),
#  ('Fruit & Nada Orange avec une touche de Goyave', 'energy_100g'),
#  ('Fruit & Nada Citron', 'energy_100g'),
#  ('Fruit revolution', 'energy_100g'),
#  (' Mango mix', 'energy_100g'),
#  ('Oasis Orange', 'energy_100g'),
#  ('Tomate, ananas & carotte', 'energy_100g'),
#  ('Jus De Fruit Frutos Rojos Y Manzana', 'energy_100g'),
#  ('Nata de Coco Lychee Flavour', 'energy_100g'),
#  ('Nata de Coco Strawberry Flavour', 'energy_100g'),
#  ("Boisson A L'aloé Vera", 'energy_100g'),
#  ('Minute maid multi fruits', 'energy_100g'),
#  ('Hand Cooked Potato Chips', 'energy_100g'),
#  ('Hand Cooked Potato Chips Mature Cheddar & Caramelized Onion',
#   'energy_100g'),
#  ('Chips salées ', 'energy_100g'),
#  ('Team Chips Dijon Mustard Flavour', 'energy_100g'),
#  ('Assortiment chips saveurs', 'energy_100g'),
#  ('Chips saveur poulet thym', 'energy_100g'),
#  ('Chips Nature x6', 'energy_100g'),
#  ('Chips saveur jambon fumé', 'energy_100g'),
#  ('Chips ondulées saveur chèvre & poivre', 'energy_100g'),
#  ("À l'heure de Chips Salées", 'energy_100g'),
#  ('Chips la classique nature', 'energy_100g'),
#  ('La classique nature', 'energy_100g'),
#  ('Saveur Chèvre Chaud & Herbes', 'energy_100g'),
#  ('Saveur Poêlée persillée', 'energy_100g'),
#  ('Vico saveur emmental ', 'energy_100g'),
#  ('Chips Dorées Nature', 'energy_100g'),
#  ('Chips campagnardes', 'energy_100g'),
#  ('Chips craquantes poulet rôti au citron et thym', 'energy_100g'),
#  ('Chips bleues pommes de terre Vitelotte', 'energy_100g'),
#  ('Les natures Paysannes', 'energy_100g'),
#  ('Chips saveur Poivre de Sichuan', 'energy_100g'),
#  ('La Chips Bio', 'energy_100g'),
#  ('Chips goût Vinaigre', 'energy_100g'),
#  ('Chips Maxi Crok', 'energy_100g'),
#  ('Mega Curves Nature', 'energy_100g'),
#  ('Mature Cheddar & Red Onion', 'energy_100g'),
#  ('Sea Salt (50% extra free)', 'energy_100g'),
#  ('Chips saveur Barbecue', 'energy_100g'),
#  ('Royal Chips Wasabi', 'energy_100g'),
#  ('Chips and Gadget Spongebob', 'energy_100g'),
#  ('Classiche Patatine', 'energy_100g'),
#  ('Chips exra-fines', 'energy_100g'),
#  ('Chips Kettle Cooked Sea Salt', 'energy_100g'),
#  ('Hand Cooked Potato Chips Black pepper & Sea salt', 'energy_100g'),
#  ('Hand Cooked Potato Chips', 'saturated-fat_100g'),
#  ('Hand Cooked Potato Chips Mature Cheddar & Caramelized Onion',
#   'saturated-fat_100g'),
#  ('Chips salées ', 'saturated-fat_100g'),
#  ('Team Chips Dijon Mustard Flavour', 'saturated-fat_100g'),
#  ('Assortiment chips saveurs', 'saturated-fat_100g'),
#  ('Chips saveur poulet thym', 'saturated-fat_100g'),
#  ('Chips Nature x6', 'saturated-fat_100g'),
#  ('Chips saveur jambon fumé', 'saturated-fat_100g'),
#  ('Chips ondulées saveur chèvre & poivre', 'saturated-fat_100g'),
#  ("À l'heure de Chips Salées", 'saturated-fat_100g'),
#  ('Chips la classique nature', 'saturated-fat_100g'),
#  ('La classique nature', 'saturated-fat_100g'),
#  ('Saveur Chèvre Chaud & Herbes', 'saturated-fat_100g'),
#  ('Saveur Poêlée persillée', 'saturated-fat_100g'),
#  ('Vico saveur emmental ', 'saturated-fat_100g'),
#  ('Chips Dorées Nature', 'saturated-fat_100g'),
#  ('Chips craquantes poulet rôti au citron et thym', 'saturated-fat_100g'),
#  ('Chips bleues pommes de terre Vitelotte', 'saturated-fat_100g'),
#  ('Les natures Paysannes', 'saturated-fat_100g'),
#  ('Chips saveur Poivre de Sichuan', 'saturated-fat_100g'),
#  ('La Chips Bio', 'saturated-fat_100g'),
#  ('Chips goût Vinaigre', 'saturated-fat_100g'),
#  ('Chips Maxi Crok', 'saturated-fat_100g'),
#  ('Mega Curves Nature', 'saturated-fat_100g'),
#  ('Mature Cheddar & Red Onion', 'saturated-fat_100g'),
#  ('Sea Salt (50% extra free)', 'saturated-fat_100g'),
#  ('Chips saveur Barbecue', 'saturated-fat_100g'),
#  ('Royal Chips Wasabi', 'saturated-fat_100g'),
#  ('Chips and Gadget Spongebob', 'saturated-fat_100g'),
#  ('Classiche Patatine', 'saturated-fat_100g'),
#  ('Chips exra-fines', 'saturated-fat_100g'),
#  ('Chips Kettle Cooked Sea Salt', 'saturated-fat_100g'),
#  ('Hand Cooked Potato Chips Black pepper & Sea salt', 'saturated-fat_100g'),
#  ('Hand Cooked Potato Chips', 'sugars_100g'),
#  ('Chips salées ', 'sugars_100g'),
#  ('Team Chips Dijon Mustard Flavour', 'sugars_100g'),
#  ('Assortiment chips saveurs', 'sugars_100g'),
#  ('Chips saveur poulet thym', 'sugars_100g'),
#  ('Chips Nature x6', 'sugars_100g'),
#  ('Chips saveur jambon fumé', 'sugars_100g'),
#  ("À l'heure de Chips Salées", 'sugars_100g'),
#  ('Chips la classique nature', 'sugars_100g'),
#  ('La classique nature', 'sugars_100g'),
#  ('Saveur Chèvre Chaud & Herbes', 'sugars_100g'),
#  ('Saveur Poêlée persillée', 'sugars_100g'),
#  ('Vico saveur emmental ', 'sugars_100g'),
#  ('Chips Dorées Nature', 'sugars_100g'),
#  ('Chips campagnardes', 'sugars_100g'),
#  ('Chips craquantes poulet rôti au citron et thym', 'sugars_100g'),
#  ('Chips bleues pommes de terre Vitelotte', 'sugars_100g'),
#  ('Les natures Paysannes', 'sugars_100g'),
#  ('Chips saveur Poivre de Sichuan', 'sugars_100g'),
#  ('La Chips Bio', 'sugars_100g'),
#  ('Chips goût Vinaigre', 'sugars_100g'),
#  ('Chips Maxi Crok', 'sugars_100g'),
#  ('Mega Curves Nature', 'sugars_100g'),
#  ('Mature Cheddar & Red Onion', 'sugars_100g'),
#  ('Sea Salt (50% extra free)', 'sugars_100g'),
#  ('Chips saveur Barbecue', 'sugars_100g'),
#  ('Royal Chips Wasabi', 'sugars_100g'),
#  ('Chips and Gadget Spongebob', 'sugars_100g'),
#  ('Classiche Patatine', 'sugars_100g'),
#  ('Chips exra-fines', 'sugars_100g'),
#  ('Chips Kettle Cooked Sea Salt', 'sugars_100g'),
#  ('Hand Cooked Potato Chips Black pepper & Sea salt', 'sugars_100g'),
#  ('Hand Cooked Potato Chips Mature Cheddar & Caramelized Onion', 'salt_100g'),
#  ('Chips salées ', 'salt_100g'),
#  ('Team Chips Dijon Mustard Flavour', 'salt_100g'),
#  ('Assortiment chips saveurs', 'salt_100g'),
#  ('Chips saveur poulet thym', 'salt_100g'),
#  ('Chips Nature x6', 'salt_100g'),
#  ('Chips saveur jambon fumé', 'salt_100g'),
#  ('Chips ondulées saveur chèvre & poivre', 'salt_100g'),
#  ("À l'heure de Chips Salées", 'salt_100g'),
#  ('Chips la classique nature', 'salt_100g'),
#  ('La classique nature', 'salt_100g'),
#  ('Saveur Chèvre Chaud & Herbes', 'salt_100g'),
#  ('Saveur Poêlée persillée', 'salt_100g'),
#  ('Vico saveur emmental ', 'salt_100g'),
#  ('Chips Dorées Nature', 'salt_100g'),
#  ('Chips campagnardes', 'salt_100g'),
#  ('Chips bleues pommes de terre Vitelotte', 'salt_100g'),
#  ('Les natures Paysannes', 'salt_100g'),
#  ('Chips saveur Poivre de Sichuan', 'salt_100g'),
#  ('La Chips Bio', 'salt_100g'),
#  ('Chips goût Vinaigre', 'salt_100g'),
#  ('Chips Maxi Crok', 'salt_100g'),
#  ('Mega Curves Nature', 'salt_100g'),
#  ('Mature Cheddar & Red Onion', 'salt_100g'),
#  ('Sea Salt (50% extra free)', 'salt_100g'),
#  ('Chips saveur Barbecue', 'salt_100g'),
#  ('Royal Chips Wasabi', 'salt_100g'),
#  ('Chips and Gadget Spongebob', 'salt_100g'),
#  ('Classiche Patatine', 'salt_100g'),
#  ('Chips exra-fines', 'salt_100g'),
#  ('Chips Kettle Cooked Sea Salt', 'salt_100g'),
#  ('Hand Cooked Potato Chips Black pepper & Sea salt', 'salt_100g'),
#  ('Hand Cooked Potato Chips Mature Cheddar & Caramelized Onion',
#   'sodium_100g'),
#  ('Chips salées ', 'sodium_100g'),
#  ('Team Chips Dijon Mustard Flavour', 'sodium_100g'),
#  ('Assortiment chips saveurs', 'sodium_100g'),
#  ('Chips saveur poulet thym', 'sodium_100g'),
#  ('Chips Nature x6', 'sodium_100g'),
#  ('Chips saveur jambon fumé', 'sodium_100g'),
#  ('Chips ondulées saveur chèvre & poivre', 'sodium_100g'),
#  ("À l'heure de Chips Salées", 'sodium_100g'),
#  ('Chips la classique nature', 'sodium_100g'),
#  ('La classique nature', 'sodium_100g'),
#  ('Saveur Chèvre Chaud & Herbes', 'sodium_100g'),
#  ('Saveur Poêlée persillée', 'sodium_100g'),
#  ('Vico saveur emmental ', 'sodium_100g'),
#  ('Chips Dorées Nature', 'sodium_100g'),
#  ('Chips campagnardes', 'sodium_100g'),
#  ('Chips bleues pommes de terre Vitelotte', 'sodium_100g'),
#  ('Les natures Paysannes', 'sodium_100g'),
#  ('Chips saveur Poivre de Sichuan', 'sodium_100g'),
#  ('La Chips Bio', 'sodium_100g'),
#  ('Chips goût Vinaigre', 'sodium_100g'),
#  ('Chips Maxi Crok', 'sodium_100g'),
#  ('Mega Curves Nature', 'sodium_100g'),
#  ('Mature Cheddar & Red Onion', 'sodium_100g'),
#  ('Sea Salt (50% extra free)', 'sodium_100g'),
#  ('Chips saveur Barbecue', 'sodium_100g'),
#  ('Royal Chips Wasabi', 'sodium_100g'),
#  ('Chips and Gadget Spongebob', 'sodium_100g'),
#  ('Classiche Patatine', 'sodium_100g'),
#  ('Chips exra-fines', 'sodium_100g'),
#  ('Chips Kettle Cooked Sea Salt', 'sodium_100g'),
#  ('Hand Cooked Potato Chips Black pepper & Sea salt', 'sodium_100g'),
#  ('Wild Berry Skittles', 'energy_100g'),
#  ('Bonbons tendres ', 'energy_100g'),
#  ('Les Minis carambar fête', 'energy_100g'),
#  ('Bonbons goût fruit', 'energy_100g'),
#  ('Puré Apple & Honey', 'energy_100g'),
#  ('Tic Tac orange', 'energy_100g'),
#  ('Wild Berry Skittles', 'proteins_100g'),
#  ('Bonbons tendres ', 'proteins_100g'),
#  ('Les Minis carambar fête', 'proteins_100g'),
#  ('Bonbons goût fruit', 'proteins_100g'),
#  ('Tic Tac orange', 'proteins_100g'),
#  ('Limonade des neiges', 'energy_100g'),
#  ('LemonLime', 'energy_100g'),
#  ('Limonade traditionnelle :Arôme naturel de citron-citron vert',
#   'energy_100g'),
#  ("Look Limonade à l'eau de source", 'energy_100g'),
#  ("Limonade à l'arôme naturel d'agrumes", 'energy_100g'),
#  ('Limonade U Bio,', 'energy_100g'),
#  ('Limonade traditionnelle', 'energy_100g'),
#  ("Limonade à l'ancienne", 'energy_100g'),
#  ('Limonade Au Citron', 'energy_100g'),
#  ('Limonade Bio', 'energy_100g'),
#  ('Limonade artisanale', 'energy_100g'),
#  ('Limonade Délicieuse A La Myrtille', 'energy_100g'),
#  ('Limonade', 'energy_100g'),
#  ('Limonade bio', 'energy_100g'),
#  ('Bionade', 'energy_100g'),
#  ('Lemonade Blood Orange', 'energy_100g'),
#  ('Limonade Ramune', 'energy_100g'),
#  ('Lemonade', 'energy_100g'),
#  ('Lemonade Orange', 'energy_100g'),
#  ('Diet Lemonade', 'proteins_100g'),
#  ('Limonade des neiges', 'proteins_100g'),
#  ('LemonLime', 'proteins_100g'),
#  ('Limonade traditionnelle :Arôme naturel de citron-citron vert',
#   'proteins_100g'),
#  ("Look Limonade à l'eau de source", 'proteins_100g'),
#  ('Look', 'proteins_100g'),
#  ("Limonade à l'arôme naturel d'agrumes", 'proteins_100g'),
#  ('Limonade U Bio,', 'proteins_100g'),
#  ('Limonade traditionnelle', 'proteins_100g'),
#  ("Limonade à l'ancienne", 'proteins_100g'),
#  ('Limonade Au Citron', 'proteins_100g'),
#  ('Limonade Bio', 'proteins_100g'),
#  ('Limonade artisanale Fruit de la Passion', 'proteins_100g'),
#  ('Limonade artisanale', 'proteins_100g'),
#  ('Limonade Délicieuse A La Myrtille', 'proteins_100g'),
#  ('Limonade', 'proteins_100g'),
#  ('Limonade bio', 'proteins_100g'),
#  ('Mountain Dew', 'proteins_100g'),
#  ('Mate', 'proteins_100g'),
#  ('Lemonade Blood Orange', 'proteins_100g'),
#  ('Ascania limonade fraise', 'proteins_100g'),
#  ('Limonade Ramune', 'proteins_100g'),
#  ('limonade', 'proteins_100g'),
#  ('Bionina', 'proteins_100g'),
#  ('Lemonade Orange', 'proteins_100g'),
#  ("crème de marron de l'ardèche vanillée", 'energy_100g'),
#  ('Crème de marrons vanillée', 'energy_100g'),
#  ('Crème de châtaignes', 'energy_100g'),
#  ("crème de marron de l'ardèche vanillée", 'saturated-fat_100g'),
#  ('Crème de marrons vanillée', 'saturated-fat_100g'),
#  ('Crème de châtaignes', 'saturated-fat_100g'),
#  ("crème de marron de l'ardèche vanillée", 'sugars_100g'),
#  ('Crème de marrons vanillée', 'sugars_100g'),
#  ('Crème de châtaignes', 'sugars_100g'),
#  ("crème de marron de l'ardèche vanillée", 'proteins_100g'),
#  ('Crème de marrons vanillée', 'proteins_100g'),
#  ('Crème de châtaignes', 'proteins_100g'),
#  ("crème de marron de l'ardèche vanillée", 'salt_100g'),
#  ('Crème de marrons vanillée', 'salt_100g'),
#  ('Crème de châtaignes', 'salt_100g'),
#  ("crème de marron de l'ardèche vanillée", 'sodium_100g'),
#  ...]

# %%
## création de nouvelles colonnes pour identifier les outliers
nutriment_cols_ouliers=list(map(lambda x:x+'_outliers',nutriment_cols))
for col in nutriment_cols_ouliers:
    df[col]=0
# Out:
# ['product_name',
#  'categories',
#  'additives_n',
#  'ingredients_from_palm_oil_n',
#  'nutrition_grade_fr',
#  'energy_100g',
#  'saturated-fat_100g',
#  'sugars_100g',
#  'proteins_100g',
#  'salt_100g',
#  'sodium_100g',
#  'nutrition-score-fr_100g',
#  'energy_100g_ouliers',
#  'saturated-fat_100g_ouliers',
#  'sugars_100g_ouliers',
#  'proteins_100g_ouliers',
#  'salt_100g_ouliers',
#  'sodium_100g_ouliers',
#  'nutrition-score-fr_100g_ouliers',
#  'energy_100g_outliers',
#  'saturated-fat_100g_outliers',
#  'sugars_100g_outliers',
#  'proteins_100g_outliers',
#  'salt_100g_outliers',
#  'sodium_100g_outliers',
#  'nutrition-score-fr_100g_outliers']

# %%
## identification des outliers
for i,col in outliers_products:
    product=df[df['product_name']==i]
    df.loc[product.index,col+'_outliers']=1

# %%
df.to_csv('./food_outliers.csv',index=False)

# %%
product_outliers_names=list(map(lambda x: x[0],outliers_products))

# %%
import collections
print('len first ',len(product_outliers_names)) ##84956
duplicates=[item for item, count in collections.Counter(product_outliers_names).items() if count > 1] 
## 16549 produits ayant plus d'une valeur aberrante pour les variables nutritives
print('duplicates',len(duplicates))
#list(collections.OrderedDict.fromkeys(product_outliers_names))
# Out:
# len first  84956
# duplicates 16549

# %%
## identification des 18638 produits ayant des valeurs aberrantes
outliers_df=df[df['product_name'].isin(product_outliers_names)][['product_name','categories']] 
outliers_df
# Out:
#                                            product_name  \
# 226                               Pepsi, Nouveau goût !
# 454     All Buter Belgian White Chocolate Chunk Cookies
# 458                                 Stem Ginger Cookies
# 459                                 Stem Ginger Dunkers
# 664                       Aloe Vera Grape & Apple Juice
# ...                                                 ...
# 320668                          100% Pur Jus 4 agrumes
# 320681                            Spearmint sans sucres
# 320702                   Fisherman's Friend Miel-Citron
# 320734              Nature cheddar and red onion crisps
# 320763                               Thé vert Earl grey
#
#                                                categories
# 226                                         Sodas au cola
# 454                                               Cookies
# 458                                               Cookies
# 459                                               Cookies
# 664                                   boissons aux fruits
# ...                                                   ...
# 320668  Aliments et boissons à base de végétaux,Boisso...
# 320681                                            Bonbons
# 320702                                  Bonbons,Pastilles
# 320734                                             Crisps
# 320763                                         thés verts
#
# [18635 rows x 2 columns]

# %%
## suppression des valeurs aberrantes
df.drop(outliers_df.index,inplace=True)

# %%
g=sns.boxplot(data=df[nutriment_cols])
g.set_yscale("log")

# %% [markdown]
# # Imputation des valeurs manquantes des variables quantitatives

# %%
## afin d'utiliser la méthode iterativeImputer, identification des variables suffisamment corrélées entre elles
numeric_columns=df.select_dtypes(exclude=['object']).columns.tolist()
corr_matrix = df[numeric_columns].corr().abs()



sol = (corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
                  .stack()
                  .sort_values(ascending=False))
sol.head()
# Out:
# salt_100g           sodium_100g                1.000000
# saturated-fat_100g  nutrition-score-fr_100g    0.596228
# sugars_100g         nutrition-score-fr_100g    0.405827
# energy_100g         nutrition-score-fr_100g    0.375789
#                     saturated-fat_100g         0.290391
# dtype: float64

# %%
##

# %%
## les colonnes sel et sodium ont une corrélation positive absolue égale à 1, et sont confondues
## suppression de la variable sodium (sodium_100g)
df.drop(columns=['sodium_100g'],axis=1,inplace=True)
numeric_columns.remove('sodium_100g')
## les colonnes energy_100g,nutrition-score-fr_100g et saturated-fat_100g  corrélées positivement entre elles.
 # Utilisation Iterativeimputer pour imputer les valeurs manquantes
correlated_columns=['nutrition-score-fr_100g','saturated-fat_100g']
                    
un_correlated_columns=[x for x in numeric_columns if x not in correlated_columns]

un_correlated_columns
# Out:
# ['additives_n',
#  'ingredients_from_palm_oil_n',
#  'energy_100g',
#  'sugars_100g',
#  'proteins_100g',
#  'salt_100g',
#  'energy_100g_ouliers',
#  'saturated-fat_100g_ouliers',
#  'sugars_100g_ouliers',
#  'proteins_100g_ouliers',
#  'salt_100g_ouliers',
#  'sodium_100g_ouliers',
#  'nutrition-score-fr_100g_ouliers',
#  'energy_100g_outliers',
#  'saturated-fat_100g_outliers',
#  'sugars_100g_outliers',
#  'proteins_100g_outliers',
#  'salt_100g_outliers',
#  'sodium_100g_outliers',
#  'nutrition-score-fr_100g_outliers']

# %%
#imputation des valeurs nulles des variables corrélées entre elles par IterativeImputer

impute_it=IterativeImputer(missing_values=np.nan,min_value=0)
results=impute_it.fit_transform(df[correlated_columns])
df_imputed = pd.DataFrame(data = results,columns = correlated_columns)

# %%
#imputation des valeurs nulles des variables non corrélées entre elles par KNNimputer

        
        
imputer = KNNImputer()
results = imputer.fit_transform(df[un_correlated_columns])
df_imputed_2=pd.DataFrame(data = results,columns = un_correlated_columns)

# %%
df[correlated_columns]=df_imputed.values
df[un_correlated_columns]=df_imputed_2.values

# %%
## les variables quantitatives sont à 100% complètes
df[numeric_columns].isnull().sum()/len(df)*100
# Out:
# additives_n                         0.0
# ingredients_from_palm_oil_n         0.0
# energy_100g                         0.0
# saturated-fat_100g                  0.0
# sugars_100g                         0.0
# proteins_100g                       0.0
# salt_100g                           0.0
# nutrition-score-fr_100g             0.0
# energy_100g_ouliers                 0.0
# saturated-fat_100g_ouliers          0.0
# sugars_100g_ouliers                 0.0
# proteins_100g_ouliers               0.0
# salt_100g_ouliers                   0.0
# sodium_100g_ouliers                 0.0
# nutrition-score-fr_100g_ouliers     0.0
# energy_100g_outliers                0.0
# saturated-fat_100g_outliers         0.0
# sugars_100g_outliers                0.0
# proteins_100g_outliers              0.0
# salt_100g_outliers                  0.0
# sodium_100g_outliers                0.0
# nutrition-score-fr_100g_outliers    0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25840 entries, 106 to 320757
# Data columns (total 25 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   product_name                      25840 non-null  object
#  1   categories                        13039 non-null  object
#  2   additives_n                       25840 non-null  float64
#  3   ingredients_from_palm_oil_n       25840 non-null  float64
#  4   nutrition_grade_fr                24297 non-null  object
#  5   energy_100g                       25840 non-null  float64
#  6   saturated-fat_100g                25840 non-null  float64
#  7   sugars_100g                       25840 non-null  float64
#  8   proteins_100g                     25840 non-null  float64
#  9   salt_100g                         25840 non-null  float64
#  10  nutrition-score-fr_100g           25840 non-null  float64
#  11  energy_100g_ouliers               25840 non-null  float64
#  12  saturated-fat_100g_ouliers        25840 non-null  float64
#  13  sugars_100g_ouliers               25840 non-null  float64
#  14  proteins_100g_ouliers             25840 non-null  float64
#  15  salt_100g_ouliers                 25840 non-null  float64
#  16  sodium_100g_ouliers               25840 non-null  float64
#  17  nutrition-score-fr_100g_ouliers   25840 non-null  float64
#  18  energy_100g_outliers              25840 non-null  float64
#  19  saturated-fat_100g_outliers       25840 non-null  float64
#  20  sugars_100g_outliers              25840 non-null  float64
#  21  proteins_100g_outliers            25840 non-null  float64
#  22  salt_100g_outliers                25840 non-null  float64
#  23  sodium_100g_outliers              25840 non-null  float64
#  24  nutrition-score-fr_100g_outliers  25840 non-null  float64
# dtypes: float64(22), object(3)
# memory usage: 5.1+ MB

# %% [markdown]
# # Imputation des valeurs manquantes des variables qualitatives

# %%
qualitative_columns=df.select_dtypes(include=['object']).columns.tolist()

# %%
df[qualitative_columns].isnull().sum()/len(df)*100
# Out:
# product_name           0.000000
# categories            49.539474
# nutrition_grade_fr     5.971362
# dtype: float64

# %%
 

df[qualitative_columns]=df[qualitative_columns].fillna("unknown")

# %%
df.isnull().sum()/len(df)*100
# Out:
# product_name                        0.0
# categories                          0.0
# additives_n                         0.0
# ingredients_from_palm_oil_n         0.0
# nutrition_grade_fr                  0.0
# energy_100g                         0.0
# saturated-fat_100g                  0.0
# sugars_100g                         0.0
# proteins_100g                       0.0
# salt_100g                           0.0
# nutrition-score-fr_100g             0.0
# energy_100g_ouliers                 0.0
# saturated-fat_100g_ouliers          0.0
# sugars_100g_ouliers                 0.0
# proteins_100g_ouliers               0.0
# salt_100g_ouliers                   0.0
# sodium_100g_ouliers                 0.0
# nutrition-score-fr_100g_ouliers     0.0
# energy_100g_outliers                0.0
# saturated-fat_100g_outliers         0.0
# sugars_100g_outliers                0.0
# proteins_100g_outliers              0.0
# salt_100g_outliers                  0.0
# sodium_100g_outliers                0.0
# nutrition-score-fr_100g_outliers    0.0
# dtype: float64

# %%
df.describe()
# Out:
#         additives_n  ingredients_from_palm_oil_n    energy_100g  \
# count  25840.000000                 25840.000000   25840.000000
# mean       2.282469                     0.069667    1188.432024
# std        2.085391                     0.218150    1375.070184
# min        0.000000                     0.000000       0.000000
# 25%        1.000000                     0.000000     526.000000
# 50%        2.000000                     0.000000    1100.000000
# 75%        3.000000                     0.000000    1707.250000
# max       20.000000                     2.000000  182764.000000
#
#        saturated-fat_100g   sugars_100g  proteins_100g     salt_100g  \
# count        25840.000000  25840.000000   25840.000000  25840.000000
# mean             6.369728     16.198501       8.165927      1.531187
# std              8.738202     20.702038       8.499789      5.392417
# min              0.000000      0.000000       0.000000      0.000000
# 25%              0.700000      1.200000       2.200000      0.100000
# 50%              3.200000      5.700000       6.000000      0.660000
# 75%              8.800000     26.000000      11.000000      1.400000
# max            100.000000    100.000000     100.000000    100.000000
#
#        nutrition-score-fr_100g  energy_100g_ouliers  \
# count             25840.000000              25840.0
# mean                 10.934562                  0.0
# std                   7.676706                  0.0
# min                   0.000000                  0.0
# 25%                   4.000000                  0.0
# 50%                  11.000000                  0.0
# 75%                  17.000000                  0.0
# max                  42.297879                  0.0
#
#        saturated-fat_100g_ouliers  ...  salt_100g_ouliers  \
# count                     25840.0  ...            25840.0
# mean                          0.0  ...                0.0
# std                           0.0  ...                0.0
# min                           0.0  ...                0.0
# 25%                           0.0  ...                0.0
# 50%                           0.0  ...                0.0
# 75%                           0.0  ...                0.0
# max                           0.0  ...                0.0
#
#        sodium_100g_ouliers  nutrition-score-fr_100g_ouliers  \
# count              25840.0                          25840.0
# mean                   0.0                              0.0
# std                    0.0                              0.0
# min                    0.0                              0.0
# 25%                    0.0                              0.0
# 50%                    0.0                              0.0
# 75%                    0.0                              0.0
# max                    0.0                              0.0
#
#        energy_100g_outliers  saturated-fat_100g_outliers  \
# count               25840.0                      25840.0
# mean                    0.0                          0.0
# std                     0.0                          0.0
# min                     0.0                          0.0
# 25%                     0.0                          0.0
# 50%                     0.0                          0.0
# 75%                     0.0                          0.0
# max                     0.0                          0.0
#
#        sugars_100g_outliers  proteins_100g_outliers  salt_100g_outliers  \
# count               25840.0                 25840.0             25840.0
# mean                    0.0                     0.0                 0.0
# std                     0.0                     0.0                 0.0
# min                     0.0                     0.0                 0.0
# 25%                     0.0                     0.0                 0.0
# 50%                     0.0                     0.0                 0.0
# 75%                     0.0                     0.0                 0.0
# max                     0.0                     0.0                 0.0
#
#        sodium_100g_outliers  nutrition-score-fr_100g_outliers
# count               25840.0                           25840.0
# mean                    0.0                               0.0
# std                     0.0                               0.0
# min                     0.0                               0.0
# 25%                     0.0                               0.0
# 50%                     0.0                               0.0
# 75%                     0.0                               0.0
# max                     0.0                               0.0
#
# [8 rows x 22 columns]

# %%
## après imputation des valeurs manquantes, on remarque des valeurs aberrantes pour la variables energy
## nous allons identifier ses valeurs aberrantes
def find_outliers(col,df):

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    outliers= df[((df[col] < (Q1 - 1.5 * IQR)) |(df[col] > (Q3 + 1.5 * IQR))).any(axis=1)]
   
  
    if len(outliers)>0:
       
        return outliers['product_name'].values.tolist()
    else:
        #print('no outliers for column '+str(col[0])+' and category '+str(category))
        return []
outliers_energy=find_outliers(['energy_100g'],df)
outliers_energy_df=df[df['product_name'].isin(outliers_energy)][['product_name','categories','energy_100g']]
outliers_energy_df ##225 produits
# Out:
#                                  product_name  \
# 56561                           Tawny' Orange
# 68125   Beurre D'arachide (sans Sel Ni Sucre)
# 174965  Sill Matjes, Matjesfilets Geschnitten
# 177219                      Frites & Fritures
# 178384          Bio Leinöl nativ kaltgestellt
# ...                                       ...
# 314246                          Beurre A Cuir
# 316993                     virgin coconut oil
# 317235               Dee Thai Huile De Sésame
# 319695                                   Miel
# 320561                 Chicken Cup Of Noodles
#
#                                          categories  energy_100g
# 56561                                       unknown       5054.0
# 68125                                       unknown       3766.0
# 174965                                      unknown       3494.0
# 177219  Matières grasses végétales,Huiles de Coprah       3700.0
# 178384                                      unknown       3489.0
# ...                                             ...          ...
# 314246                                      unknown       3582.0
# 316993                                      unknown       3766.0
# 317235                                      unknown       3766.0
# 319695                                      unknown       5925.0
# 320561                                      unknown       4602.0
#
# [225 rows x 3 columns]

# %%
## identification de tous les outliers de la variable energy dont la catégorie est inconnue
outliers_energy_df=outliers_energy_df[df['categories']=='unknown']
outliers_energy_df ## 147 outliers dont la catégorie est inconnue
# Out:
# /home/amadou/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                                              product_name categories  \
# 56561                                       Tawny' Orange    unknown
# 68125               Beurre D'arachide (sans Sel Ni Sucre)    unknown
# 174965              Sill Matjes, Matjesfilets Geschnitten    unknown
# 178384                      Bio Leinöl nativ kaltgestellt    unknown
# 178567  Confiserie Firenze Apfel Streuselkuchen Tiefge...    unknown
# ...                                                   ...        ...
# 314246                                      Beurre A Cuir    unknown
# 316993                                 virgin coconut oil    unknown
# 317235                           Dee Thai Huile De Sésame    unknown
# 319695                                               Miel    unknown
# 320561                             Chicken Cup Of Noodles    unknown
#
#         energy_100g
# 56561        5054.0
# 68125        3766.0
# 174965       3494.0
# 178384       3489.0
# 178567       4197.0
# ...             ...
# 314246       3582.0
# 316993       3766.0
# 317235       3766.0
# 319695       5925.0
# 320561       4602.0
#
# [147 rows x 3 columns]

# %%
## identification et suppression de tous les outliers de la variable energy dont la catégorie est inconnue
df.drop(df[df['product_name'].isin(outliers_energy_df['product_name'].values)].index, inplace = True)

# %%
df.describe()
# Out:
#         additives_n  ingredients_from_palm_oil_n   energy_100g  \
# count  25693.000000                 25693.000000  25693.000000
# mean       2.281049                     0.069482   1163.928793
# std        2.089730                     0.218629    748.650245
# min        0.000000                     0.000000      0.000000
# 25%        1.000000                     0.000000    523.000000
# 50%        2.000000                     0.000000   1092.000000
# 75%        3.200000                     0.000000   1700.000000
# max       20.000000                     2.000000  15481.000000
#
#        saturated-fat_100g   sugars_100g  proteins_100g     salt_100g  \
# count        25693.000000  25693.000000   25693.000000  25693.000000
# mean             6.304049     16.226355       8.185423      1.535825
# std              8.482682     20.692567       8.498887      5.404739
# min              0.000000      0.000000       0.000000      0.000000
# 25%              0.700000      1.200000       2.300000      0.100000
# 50%              3.200000      5.800000       6.000000      0.670000
# 75%              8.700000     26.000000      11.000000      1.400000
# max            100.000000    100.000000     100.000000    100.000000
#
#        nutrition-score-fr_100g  energy_100g_ouliers  \
# count             25693.000000              25693.0
# mean                 10.888556                  0.0
# std                   7.664808                  0.0
# min                   0.000000                  0.0
# 25%                   4.000000                  0.0
# 50%                  11.000000                  0.0
# 75%                  16.000000                  0.0
# max                  42.297879                  0.0
#
#        saturated-fat_100g_ouliers  ...  salt_100g_ouliers  \
# count                     25693.0  ...            25693.0
# mean                          0.0  ...                0.0
# std                           0.0  ...                0.0
# min                           0.0  ...                0.0
# 25%                           0.0  ...                0.0
# 50%                           0.0  ...                0.0
# 75%                           0.0  ...                0.0
# max                           0.0  ...                0.0
#
#        sodium_100g_ouliers  nutrition-score-fr_100g_ouliers  \
# count              25693.0                          25693.0
# mean                   0.0                              0.0
# std                    0.0                              0.0
# min                    0.0                              0.0
# 25%                    0.0                              0.0
# 50%                    0.0                              0.0
# 75%                    0.0                              0.0
# max                    0.0                              0.0
#
#        energy_100g_outliers  saturated-fat_100g_outliers  \
# count               25693.0                      25693.0
# mean                    0.0                          0.0
# std                     0.0                          0.0
# min                     0.0                          0.0
# 25%                     0.0                          0.0
# 50%                     0.0                          0.0
# 75%                     0.0                          0.0
# max                     0.0                          0.0
#
#        sugars_100g_outliers  proteins_100g_outliers  salt_100g_outliers  \
# count               25693.0                 25693.0             25693.0
# mean                    0.0                     0.0                 0.0
# std                     0.0                     0.0                 0.0
# min                     0.0                     0.0                 0.0
# 25%                     0.0                     0.0                 0.0
# 50%                     0.0                     0.0                 0.0
# 75%                     0.0                     0.0                 0.0
# max                     0.0                     0.0                 0.0
#
#        sodium_100g_outliers  nutrition-score-fr_100g_outliers
# count               25693.0                           25693.0
# mean                    0.0                               0.0
# std                     0.0                               0.0
# min                     0.0                               0.0
# 25%                     0.0                               0.0
# 50%                     0.0                               0.0
# 75%                     0.0                               0.0
# max                     0.0                               0.0
#
# [8 rows x 22 columns]

# %%
df=df.loc[:, ~df.columns.isin(nutriment_cols_ouliers)]

# %%
df.to_csv('./cleaned_food.csv',index=False)
